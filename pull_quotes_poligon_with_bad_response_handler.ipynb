# %%
import pandas as pd
import numpy as np
import datetime
import requests
from string import Template
import pytz
import math
import logging
import time
from pandasql import sqldf

# %%
pd.options.display.max_rows = 50
pd.options.display.max_columns = 100

# %%
# API  STUFF
API_KEY = 'qf_ZzJ56DKvoDrfdw3OVFlzGW_UfZ9el'
OPTIONS_URL = Template('https://api.polygon.io/v2/aggs/ticker/$ticker/range/$multiplier/minute/$start_date/$end_date?adjusted=true&sort=asc&limit=50000')
EQUITY_URL =  Template('https://api.polygon.io/v2/aggs/ticker/$ticker/range/$multiplier/minute/$start_date/$end_date?adjusted=true&sort=asc&limit=50000')

# logger stuff
console_logger = logging.getLogger('console_logger')
file_logger = logging.getLogger('file_logger')
file_logger.setLevel(logging.DEBUG)
console_logger.setLevel(logging.DEBUG)
file_handler = logging.FileHandler('research_options_05-11-24.log')
console_handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)
file_logger.addHandler(file_handler)
console_logger.addHandler(console_handler)
# logger stuff end

#pandassql stuff
mysqldf = lambda q: sqldf(q, globals())

# %%
startDate = datetime.date(2024,1,1)
endDate = datetime.date(2024,5,30)
equity_symbol = 'SPY'
max_expiry_dte = 2
max_strikes_from_open_price = 0.03 # pct wise from  open equity price
strike_step = 1

# %%
def generateOptionsAPIRequestQuotes(optionstring:str, startDate: datetime.date, endDate: datetime.date, minutes_freq:int):
    CSV = False
    headers = {
             'Authorization': f"Bearer {API_KEY}",
        }
    if CSV: headers['Accept'] = 'text/csv'
    url = OPTIONS_URL.substitute(
                ticker = optionstring,
                multiplier = minutes_freq,
                start_date = startDate.strftime('%Y-%m-%d'),
                end_date = endDate.strftime('%Y-%m-%d')
    )
    response = requests.get(url, headers=headers)
    return response
def generateEquityAPIRequestQuotes(ticker: str,startDate: datetime.date,endDate: datetime.date, minutes_freq:int):
    headers = {
        'Authorization': f"Bearer {API_KEY}"
    }
    CSV = False
    if CSV: headers['Accept'] = 'text/csv'
    url = EQUITY_URL.substitute(
                ticker = ticker,
                multiplier = minutes_freq,
                start_date = startDate,
                end_date = endDate
        )
    response = requests.get(url, headers=headers)
    return response
def getOptionsData(ticker,startDate,endDate,minutes_freq):
    def enhancePulledDataFromPolygon(df:pd.DataFrame, optionticker:str,
                                     option_full_name: str,
                                     optiontype: str, option_strike:float,
                                     option_expiry_date: datetime.date):
        """Gets df obtained from Polygon api request and enriches with 
           columns such as ticker, strike, option type, expiry date
           since the data from Polygon doesn't contain this.
           option parametes are passed from the calling func as they were used to query
           poligon API
         """
        df['ticker'] = optionticker
        df['full_name'] = option_full_name
        df['type'] = optiontype
        df['strike'] = option_strike
        df['expiry'] = option_expiry_date
        return df
    dates_range = pd.date_range(start=startDate, end=endDate, freq='D')
    equity_quotes = generateEquityAPIRequestQuotes(ticker,startDate,endDate,minutes_freq)
    equity_df = pd.DataFrame()
    if equity_quotes.status_code == 200:
        equity_df = pd.DataFrame(equity_quotes.json()['results'])
        equity_df = equity_df.rename(
            columns={"v": "volume", "vw": "volume_weighted", "o": "open", "c": "close",
                        "h": "high", "l": "low", "t": "timestamp", "n": "number of trades",
                        "a": "trade conditions"})
        equity_df['time_converted'] = pd.to_datetime(
            equity_df["timestamp"], unit="ms").dt.tz_localize(
                pytz.UTC).dt.tz_convert("US/Eastern").dt.tz_localize(None)
    else:
        print (equity_quotes.text)
        raise RuntimeError("Error when processing API call to equity prices")
    
    
    df_quotes = []
    for day in dates_range:
        # first pull equity open price for this day
        try:
            # pull  first open price in candle after 9.30
            central_price = equity_df[(equity_df['time_converted'].dt.date == day.date()) & 
                                            (equity_df['time_converted'].dt.time > datetime.time(9,30))]['open'].iloc[0]
            # Calculate strike math
            strike_upper_limit = math.ceil(central_price*(1+max_strikes_from_open_price))
            strike_lower_limit = math.floor(central_price*(1-max_strikes_from_open_price))
            strike_range = list(range(strike_lower_limit,strike_upper_limit,strike_step))
        except IndexError:
            file_logger.warning('Could not find equity date for date: ' + str(day.date()))   
            console_logger.warning('Could not find equity date for date: ' + str(day.date()))
            continue   
        if np.is_busday(day.date()):
            # create API requests for days having DTE 0 and less than max_expiry_dte
            for DTE in range(0,max_expiry_dte+1):
                # for each date pull all options expiring on this date and within max_strikes_from_open_price
                contract_date = (day.date() + pd.tseries.offsets.BDay(n = DTE))
                                 #datetime.timedelta(days = DTE))
                # if the contract expiry date is weekend (sat,sun) then skip
                if contract_date.isoweekday() in [6,7]:
                    file_logger.info(f'Contract expiry date {contract_date} is on expiring on Weekend for options trading on {day.date}. Skipping this expiry date ')
                    console_logger.debug(f'Contract expiry date {contract_date} is on expiring on Weekend for options trading on {day.date}. Skipping this expiry date ')
                    continue
                else:
                    contract_date = contract_date.strftime('%y%m%d')
                
                try:
                    for strike in strike_range:
                        #for each strike retrieve for specific contract expiry date (DTE(contract_date)) for specific date (day) quotes
                        # example: "O:SPY230519C00417000"
                        call_contract_ticker = 'O:SPY'+ contract_date+'C'+'00'+str(int(strike)*1000)
                        put_contract_ticker =  'O:SPY'+ contract_date+'P'+'00'+str(int(strike)*1000)
                        file_logger.info('Pulling call: ' + call_contract_ticker)
                        call_response = generateOptionsAPIRequestQuotes(call_contract_ticker,day,day,minutes_freq)
                        if call_response.status_code != 200:
                            console_logger.debug(call_contract_ticker)
                            console_logger.debut(call_response.text)
                            raise RuntimeError("API returned not success when trying to get call options")
                        
                        # potentially maybe zero results since extra holidays or data corruption, then skip it
                        if int(call_response.json()['resultsCount']) > 0:
                            df_strike_call = pd.DataFrame(call_response.json()['results'])
                            df_strike_call = enhancePulledDataFromPolygon(
                                        df=df_strike_call, optionticker=ticker,option_full_name=call_contract_ticker,
                                        optiontype='call', option_strike=strike,
                                        option_expiry_date=contract_date
                                    )
                            df_strike_call['equity_start_price'] = central_price
                            df_quotes.append(df_strike_call)
                        else:
                            file_logger.debug(f'!!!!**********Missing Call contract from API return******')
                            file_logger.debug(call_contract_ticker)
                            console_logger.debug(f'!!!!**********Missing Call contract******')
                            console_logger.debug(call_contract_ticker)
                        
                        file_logger.info('Pulling put: ' + put_contract_ticker)
                        put_response = generateOptionsAPIRequestQuotes(put_contract_ticker,day,day,minutes_freq)
                        if put_response.status_code != 200:
                            console_logger.debug(put_contract_ticker)
                            console_logger.debut(put_response.text)
                            raise RuntimeError("API returned not success when trying to get put options")
                        
                        if int(put_response.json()['resultsCount']) > 0:
                            df_strike_put = pd.DataFrame(put_response.json()['results'])
                            df_strike_put = enhancePulledDataFromPolygon(
                                        df=df_strike_put, optionticker=ticker,option_full_name=put_contract_ticker,
                                        optiontype='put', option_strike=strike,
                                        option_expiry_date=contract_date
                                    )
                            df_strike_put['equity_start_price'] = central_price
                            df_quotes.append(df_strike_put)
                        else:
                            file_logger.debug(f'!!!!**********Missing Put contract from API return******')
                            file_logger.debug(put_contract_ticker)
                            console_logger.debug(f'!!!!**********Missing Put contract******')
                            console_logger.debug(put_contract_ticker)
                        file_logger.info(f"""Appended these file contracts for day {day.date()}:{call_contract_ticker} and  {put_contract_ticker}""")
                        time.sleep(0.5)

                        # temp code to randomly generate exception to see the logic
                        # if np.random.randint(0,100) > 95:
                        #     raise RuntimeError('Randomly generated exception')
                except Exception as e:
                    console_logger.error(f'Error processing day {day.date()} and DTE {DTE}')
                    console_logger.error(e)
                    return {
                        'options_quotes': df_quotes,
                        'equity_quotes': equity_df
                    }

                console_logger.debug(f'Processed expiry date {DTE} for day {day.date()}')
        console_logger.debug(f'************Finished processing day: {day.date()}***************')        
    console_logger.debug(f'************Finished running function***************')        
    file_logger.debug(f'************Finished running function***************')        
    return {
        'options_quotes': df_quotes,
        'equity_quotes' : equity_df
    }

# %%
## main body
file_logger.info('*****************************New Run***********************************')
# response is dict with options data in ['options_quotes] (list of options dfs) and equity data in ['equity_quotes] - df
data = getOptionsData('SPY',datetime.date(2024,9,1), datetime.date(2024,11,30),15)
# Out:
# 2025-03-27 12:00:10,212 - console_logger - WARNING - Could not find equity date for date: 2024-09-01
# 2025-03-27 12:00:10,217 - console_logger - WARNING - Could not find equity date for date: 2024-09-02
# 2025-03-27 12:00:35,978 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:00:35,980 - console_logger - DEBUG - O:SPY240903C00576000
# 2025-03-27 12:00:36,053 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:00:36,054 - console_logger - DEBUG - O:SPY240903P00576000
# 2025-03-27 12:00:36,555 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-03
# 2025-03-27 12:01:01,221 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:01:01,222 - console_logger - DEBUG - O:SPY240904P00573000
# 2025-03-27 12:01:01,934 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:01:01,935 - console_logger - DEBUG - O:SPY240904P00574000
# 2025-03-27 12:01:03,846 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-03
# 2025-03-27 12:01:26,368 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:01:26,369 - console_logger - DEBUG - O:SPY240905P00571000
# 2025-03-27 12:01:28,916 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:01:28,917 - console_logger - DEBUG - O:SPY240905P00574000
# 2025-03-27 12:01:30,292 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:01:30,292 - console_logger - DEBUG - O:SPY240905P00576000
# 2025-03-27 12:01:30,794 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-03
# 2025-03-27 12:01:30,795 - console_logger - DEBUG - ************Finished processing day: 2024-09-03***************
# 2025-03-27 12:01:31,076 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:01:31,076 - console_logger - DEBUG - O:SPY240904C00534000
# 2025-03-27 12:01:56,003 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-04
# 2025-03-27 12:02:22,312 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-04
# 2025-03-27 12:02:47,719 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-04
# 2025-03-27 12:02:47,721 - console_logger - DEBUG - ************Finished processing day: 2024-09-04***************
# 2025-03-27 12:03:14,140 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-05
# 2025-03-27 12:03:39,619 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-05
# 2025-03-27 12:04:04,001 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-05
# 2025-03-27 12:04:04,002 - console_logger - DEBUG - ************Finished processing day: 2024-09-05***************
# 2025-03-27 12:04:29,906 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-06
# 2025-03-27 12:04:55,222 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-06
# 2025-03-27 12:05:18,205 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:05:18,206 - console_logger - DEBUG - O:SPY240910P00565000
# 2025-03-27 12:05:18,929 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:05:18,930 - console_logger - DEBUG - O:SPY240910P00566000
# 2025-03-27 12:05:19,432 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-06
# 2025-03-27 12:05:19,432 - console_logger - DEBUG - ************Finished processing day: 2024-09-06***************
# 2025-03-27 12:05:19,437 - console_logger - WARNING - Could not find equity date for date: 2024-09-07
# 2025-03-27 12:05:19,445 - console_logger - WARNING - Could not find equity date for date: 2024-09-08
# 2025-03-27 12:05:19,523 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:05:19,524 - console_logger - DEBUG - O:SPY240909C00528000
# 2025-03-27 12:05:44,888 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-09
# 2025-03-27 12:06:09,322 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-09
# 2025-03-27 12:06:09,411 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:06:09,412 - console_logger - DEBUG - O:SPY240911C00528000
# 2025-03-27 12:06:35,487 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-09
# 2025-03-27 12:06:35,487 - console_logger - DEBUG - ************Finished processing day: 2024-09-09***************
# 2025-03-27 12:06:58,657 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-10
# 2025-03-27 12:07:21,056 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:07:21,057 - console_logger - DEBUG - O:SPY240911P00562000
# 2025-03-27 12:07:22,600 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:07:22,601 - console_logger - DEBUG - O:SPY240911P00564000
# 2025-03-27 12:07:23,101 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-10
# 2025-03-27 12:07:43,244 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:07:43,245 - console_logger - DEBUG - O:SPY240912P00559000
# 2025-03-27 12:07:45,266 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:07:45,267 - console_logger - DEBUG - O:SPY240912P00562000
# 2025-03-27 12:07:46,621 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:07:46,621 - console_logger - DEBUG - O:SPY240912P00564000
# 2025-03-27 12:07:47,122 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-10
# 2025-03-27 12:07:47,123 - console_logger - DEBUG - ************Finished processing day: 2024-09-10***************
# 2025-03-27 12:08:11,937 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-11
# 2025-03-27 12:08:37,340 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-11
# 2025-03-27 12:09:01,809 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-11
# 2025-03-27 12:09:01,810 - console_logger - DEBUG - ************Finished processing day: 2024-09-11***************
# 2025-03-27 12:09:27,823 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-12
# 2025-03-27 12:09:53,527 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-12
# 2025-03-27 12:10:17,367 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:10:17,368 - console_logger - DEBUG - O:SPY240916P00571000
# 2025-03-27 12:10:17,869 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-12
# 2025-03-27 12:10:17,870 - console_logger - DEBUG - ************Finished processing day: 2024-09-12***************
# 2025-03-27 12:10:44,160 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-13
# 2025-03-27 12:11:06,470 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:11:06,471 - console_logger - DEBUG - O:SPY240916P00574000
# 2025-03-27 12:11:07,745 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:11:07,745 - console_logger - DEBUG - O:SPY240916C00576000
# 2025-03-27 12:11:07,832 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:11:07,832 - console_logger - DEBUG - O:SPY240916P00576000
# 2025-03-27 12:11:08,407 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:11:08,408 - console_logger - DEBUG - O:SPY240916C00577000
# 2025-03-27 12:11:08,495 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:11:08,496 - console_logger - DEBUG - O:SPY240916P00577000
# 2025-03-27 12:11:08,997 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-13
# 2025-03-27 12:11:31,661 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:11:31,662 - console_logger - DEBUG - O:SPY240917P00574000
# 2025-03-27 12:11:32,970 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:11:32,971 - console_logger - DEBUG - O:SPY240917C00576000
# 2025-03-27 12:11:33,038 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:11:33,038 - console_logger - DEBUG - O:SPY240917P00576000
# 2025-03-27 12:11:33,613 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:11:33,613 - console_logger - DEBUG - O:SPY240917C00577000
# 2025-03-27 12:11:33,690 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:11:33,691 - console_logger - DEBUG - O:SPY240917P00577000
# 2025-03-27 12:11:34,193 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-13
# 2025-03-27 12:11:34,193 - console_logger - DEBUG - ************Finished processing day: 2024-09-13***************
# 2025-03-27 12:11:34,200 - console_logger - WARNING - Could not find equity date for date: 2024-09-14
# 2025-03-27 12:11:34,205 - console_logger - WARNING - Could not find equity date for date: 2024-09-15
# 2025-03-27 12:11:57,469 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:11:57,470 - console_logger - DEBUG - O:SPY240916C00576000
# 2025-03-27 12:11:57,547 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:11:57,548 - console_logger - DEBUG - O:SPY240916P00576000
# 2025-03-27 12:11:58,138 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:11:58,139 - console_logger - DEBUG - O:SPY240916C00577000
# 2025-03-27 12:11:58,218 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:11:58,218 - console_logger - DEBUG - O:SPY240916P00577000
# 2025-03-27 12:11:58,719 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-16
# 2025-03-27 12:12:20,096 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:12:20,097 - console_logger - DEBUG - O:SPY240917P00573000
# 2025-03-27 12:12:20,803 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:12:20,804 - console_logger - DEBUG - O:SPY240917P00574000
# 2025-03-27 12:12:22,068 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:12:22,069 - console_logger - DEBUG - O:SPY240917C00576000
# 2025-03-27 12:12:22,137 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:12:22,138 - console_logger - DEBUG - O:SPY240917P00576000
# 2025-03-27 12:12:22,722 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:12:22,722 - console_logger - DEBUG - O:SPY240917C00577000
# 2025-03-27 12:12:22,813 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:12:22,814 - console_logger - DEBUG - O:SPY240917P00577000
# 2025-03-27 12:12:23,314 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-16
# 2025-03-27 12:12:52,990 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:12:52,991 - console_logger - DEBUG - O:SPY240918C00576000
# 2025-03-27 12:12:53,095 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:12:53,096 - console_logger - DEBUG - O:SPY240918P00576000
# 2025-03-27 12:12:53,734 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:12:53,735 - console_logger - DEBUG - O:SPY240918C00577000
# 2025-03-27 12:12:53,827 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:12:53,827 - console_logger - DEBUG - O:SPY240918P00577000
# 2025-03-27 12:12:54,328 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-16
# 2025-03-27 12:12:54,329 - console_logger - DEBUG - ************Finished processing day: 2024-09-16***************
# 2025-03-27 12:13:14,886 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:13:14,887 - console_logger - DEBUG - O:SPY240917C00576000
# 2025-03-27 12:13:14,969 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:14,970 - console_logger - DEBUG - O:SPY240917P00576000
# 2025-03-27 12:13:15,560 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:13:15,561 - console_logger - DEBUG - O:SPY240917C00577000
# 2025-03-27 12:13:15,639 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:15,640 - console_logger - DEBUG - O:SPY240917P00577000
# 2025-03-27 12:13:16,220 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:13:16,221 - console_logger - DEBUG - O:SPY240917C00578000
# 2025-03-27 12:13:16,304 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:16,305 - console_logger - DEBUG - O:SPY240917P00578000
# 2025-03-27 12:13:16,897 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:13:16,898 - console_logger - DEBUG - O:SPY240917C00579000
# 2025-03-27 12:13:16,995 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:16,996 - console_logger - DEBUG - O:SPY240917P00579000
# 2025-03-27 12:13:18,333 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:13:18,334 - console_logger - DEBUG - O:SPY240917C00581000
# 2025-03-27 12:13:18,421 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:18,422 - console_logger - DEBUG - O:SPY240917P00581000
# 2025-03-27 12:13:19,023 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:13:19,024 - console_logger - DEBUG - O:SPY240917C00582000
# 2025-03-27 12:13:19,117 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:19,117 - console_logger - DEBUG - O:SPY240917P00582000
# 2025-03-27 12:13:19,618 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-17
# 2025-03-27 12:13:42,430 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:42,431 - console_logger - DEBUG - O:SPY240918P00578000
# 2025-03-27 12:13:44,462 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:13:44,463 - console_logger - DEBUG - O:SPY240918C00581000
# 2025-03-27 12:13:44,532 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:44,533 - console_logger - DEBUG - O:SPY240918P00581000
# 2025-03-27 12:13:45,125 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:13:45,126 - console_logger - DEBUG - O:SPY240918C00582000
# 2025-03-27 12:13:45,213 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:13:45,214 - console_logger - DEBUG - O:SPY240918P00582000
# 2025-03-27 12:13:45,715 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-17
# 2025-03-27 12:14:08,778 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:14:08,779 - console_logger - DEBUG - O:SPY240919P00579000
# 2025-03-27 12:14:10,033 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:14:10,033 - console_logger - DEBUG - O:SPY240919C00581000
# 2025-03-27 12:14:10,132 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:14:10,132 - console_logger - DEBUG - O:SPY240919P00581000
# 2025-03-27 12:14:10,712 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:14:10,713 - console_logger - DEBUG - O:SPY240919C00582000
# 2025-03-27 12:14:10,805 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:14:10,806 - console_logger - DEBUG - O:SPY240919P00582000
# 2025-03-27 12:14:11,307 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-17
# 2025-03-27 12:14:11,308 - console_logger - DEBUG - ************Finished processing day: 2024-09-17***************
# 2025-03-27 12:14:37,655 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-18
# 2025-03-27 12:15:04,207 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-18
# 2025-03-27 12:15:36,510 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-18
# 2025-03-27 12:15:36,511 - console_logger - DEBUG - ************Finished processing day: 2024-09-18***************
# 2025-03-27 12:15:59,273 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:15:59,274 - console_logger - DEBUG - O:SPY240919C00581000
# 2025-03-27 12:15:59,369 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:15:59,370 - console_logger - DEBUG - O:SPY240919P00581000
# 2025-03-27 12:15:59,940 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:15:59,940 - console_logger - DEBUG - O:SPY240919C00582000
# 2025-03-27 12:16:00,008 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:16:00,009 - console_logger - DEBUG - O:SPY240919P00582000
# 2025-03-27 12:16:00,591 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:16:00,591 - console_logger - DEBUG - O:SPY240919C00583000
# 2025-03-27 12:16:00,671 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:16:00,672 - console_logger - DEBUG - O:SPY240919P00583000
# 2025-03-27 12:16:01,261 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:16:01,262 - console_logger - DEBUG - O:SPY240919C00584000
# 2025-03-27 12:16:01,328 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:16:01,329 - console_logger - DEBUG - O:SPY240919P00584000
# 2025-03-27 12:16:02,700 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:16:02,700 - console_logger - DEBUG - O:SPY240919C00586000
# 2025-03-27 12:16:02,767 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:16:02,767 - console_logger - DEBUG - O:SPY240919P00586000
# 2025-03-27 12:16:03,268 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-19
# 2025-03-27 12:16:28,555 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:16:28,555 - console_logger - DEBUG - O:SPY240920C00586000
# 2025-03-27 12:16:28,642 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:16:28,643 - console_logger - DEBUG - O:SPY240920P00586000
# 2025-03-27 12:16:29,144 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-19
# 2025-03-27 12:16:50,953 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:16:50,954 - console_logger - DEBUG - O:SPY240923P00582000
# 2025-03-27 12:16:53,560 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:16:53,561 - console_logger - DEBUG - O:SPY240923C00586000
# 2025-03-27 12:16:53,644 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:16:53,644 - console_logger - DEBUG - O:SPY240923P00586000
# 2025-03-27 12:16:54,145 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-19
# 2025-03-27 12:16:54,145 - console_logger - DEBUG - ************Finished processing day: 2024-09-19***************
# 2025-03-27 12:17:19,232 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-20
# 2025-03-27 12:17:44,431 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-20
# 2025-03-27 12:17:46,003 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:17:46,004 - console_logger - DEBUG - O:SPY240924C00552000
# 2025-03-27 12:18:04,436 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:18:04,437 - console_logger - DEBUG - O:SPY240924P00578000
# 2025-03-27 12:18:06,457 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:18:06,457 - console_logger - DEBUG - O:SPY240924P00581000
# 2025-03-27 12:18:09,088 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-20
# 2025-03-27 12:18:09,089 - console_logger - DEBUG - ************Finished processing day: 2024-09-20***************
# 2025-03-27 12:18:09,095 - console_logger - WARNING - Could not find equity date for date: 2024-09-21
# 2025-03-27 12:18:09,103 - console_logger - WARNING - Could not find equity date for date: 2024-09-22
# 2025-03-27 12:18:34,422 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:18:34,423 - console_logger - DEBUG - O:SPY240923P00585000
# 2025-03-27 12:18:35,066 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:18:35,067 - console_logger - DEBUG - O:SPY240923C00586000
# 2025-03-27 12:18:35,783 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-23
# 2025-03-27 12:18:57,882 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:18:57,883 - console_logger - DEBUG - O:SPY240924P00581000
# 2025-03-27 12:18:59,289 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:18:59,289 - console_logger - DEBUG - O:SPY240924P00583000
# 2025-03-27 12:18:59,971 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:18:59,972 - console_logger - DEBUG - O:SPY240924P00584000
# 2025-03-27 12:19:01,287 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:19:01,288 - console_logger - DEBUG - O:SPY240924C00586000
# 2025-03-27 12:19:01,899 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-23
# 2025-03-27 12:19:01,973 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:19:01,974 - console_logger - DEBUG - O:SPY240925C00551000
# 2025-03-27 12:19:23,732 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:19:23,732 - console_logger - DEBUG - O:SPY240925P00581000
# 2025-03-27 12:19:24,452 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:19:24,452 - console_logger - DEBUG - O:SPY240925P00582000
# 2025-03-27 12:19:25,128 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:19:25,128 - console_logger - DEBUG - O:SPY240925P00583000
# 2025-03-27 12:19:25,794 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:19:25,795 - console_logger - DEBUG - O:SPY240925P00584000
# 2025-03-27 12:19:26,474 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:19:26,474 - console_logger - DEBUG - O:SPY240925P00585000
# 2025-03-27 12:19:27,184 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:19:27,185 - console_logger - DEBUG - O:SPY240925P00586000
# 2025-03-27 12:19:27,686 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-23
# 2025-03-27 12:19:27,687 - console_logger - DEBUG - ************Finished processing day: 2024-09-23***************
# 2025-03-27 12:19:30,617 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:19:30,618 - console_logger - DEBUG - O:SPY240924C00556000
# 2025-03-27 12:19:52,614 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-24
# 2025-03-27 12:19:52,729 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:19:52,729 - console_logger - DEBUG - O:SPY240925C00552000
# 2025-03-27 12:20:17,174 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:20:17,175 - console_logger - DEBUG - O:SPY240925P00586000
# 2025-03-27 12:20:17,677 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-24
# 2025-03-27 12:20:17,767 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:20:17,767 - console_logger - DEBUG - O:SPY240926C00552000
# 2025-03-27 12:20:18,759 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:20:18,759 - console_logger - DEBUG - O:SPY240926C00553000
# 2025-03-27 12:20:21,709 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:20:21,710 - console_logger - DEBUG - O:SPY240926C00557000
# 2025-03-27 12:20:39,650 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:20:39,651 - console_logger - DEBUG - O:SPY240926P00581000
# 2025-03-27 12:20:40,416 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:20:40,417 - console_logger - DEBUG - O:SPY240926P00582000
# 2025-03-27 12:20:41,941 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:20:41,942 - console_logger - DEBUG - O:SPY240926P00584000
# 2025-03-27 12:20:43,527 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:20:43,528 - console_logger - DEBUG - O:SPY240926P00586000
# 2025-03-27 12:20:44,029 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-24
# 2025-03-27 12:20:44,030 - console_logger - DEBUG - ************Finished processing day: 2024-09-24***************
# 2025-03-27 12:21:08,239 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:21:08,240 - console_logger - DEBUG - O:SPY240925P00586000
# 2025-03-27 12:21:09,492 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:21:09,492 - console_logger - DEBUG - O:SPY240925C00588000
# 2025-03-27 12:21:09,579 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:21:09,580 - console_logger - DEBUG - O:SPY240925P00588000
# 2025-03-27 12:21:10,081 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-25
# 2025-03-27 12:21:42,146 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:21:42,147 - console_logger - DEBUG - O:SPY240926P00582000
# 2025-03-27 12:21:43,410 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:21:43,411 - console_logger - DEBUG - O:SPY240926P00583000
# 2025-03-27 12:21:45,066 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:21:45,067 - console_logger - DEBUG - O:SPY240926P00585000
# 2025-03-27 12:21:45,711 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:21:45,712 - console_logger - DEBUG - O:SPY240926C00586000
# 2025-03-27 12:21:45,823 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:21:45,824 - console_logger - DEBUG - O:SPY240926P00586000
# 2025-03-27 12:21:46,656 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:21:46,657 - console_logger - DEBUG - O:SPY240926C00587000
# 2025-03-27 12:21:47,358 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:21:47,358 - console_logger - DEBUG - O:SPY240926C00588000
# 2025-03-27 12:21:47,507 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:21:47,507 - console_logger - DEBUG - O:SPY240926P00588000
# 2025-03-27 12:21:48,008 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-25
# 2025-03-27 12:22:10,517 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:22:10,518 - console_logger - DEBUG - O:SPY240927P00583000
# 2025-03-27 12:22:13,440 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:22:13,441 - console_logger - DEBUG - O:SPY240927C00587000
# 2025-03-27 12:22:13,511 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:22:13,512 - console_logger - DEBUG - O:SPY240927P00587000
# 2025-03-27 12:22:14,099 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:22:14,100 - console_logger - DEBUG - O:SPY240927C00588000
# 2025-03-27 12:22:14,170 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:22:14,170 - console_logger - DEBUG - O:SPY240927P00588000
# 2025-03-27 12:22:14,671 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-25
# 2025-03-27 12:22:14,672 - console_logger - DEBUG - ************Finished processing day: 2024-09-25***************
# 2025-03-27 12:22:35,663 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:22:35,664 - console_logger - DEBUG - O:SPY240926C00586000
# 2025-03-27 12:22:36,351 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:22:36,352 - console_logger - DEBUG - O:SPY240926C00587000
# 2025-03-27 12:22:37,137 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:22:37,137 - console_logger - DEBUG - O:SPY240926P00588000
# 2025-03-27 12:22:37,845 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:22:37,846 - console_logger - DEBUG - O:SPY240926P00589000
# 2025-03-27 12:22:39,063 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-26
# 2025-03-27 12:23:01,160 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:23:01,160 - console_logger - DEBUG - O:SPY240927P00587000
# 2025-03-27 12:23:02,717 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:23:02,718 - console_logger - DEBUG - O:SPY240927P00589000
# 2025-03-27 12:23:03,964 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-26
# 2025-03-27 12:23:25,793 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:23:25,794 - console_logger - DEBUG - O:SPY240930P00586000
# 2025-03-27 12:23:26,525 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:23:26,526 - console_logger - DEBUG - O:SPY240930P00587000
# 2025-03-27 12:23:27,212 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:23:27,213 - console_logger - DEBUG - O:SPY240930P00588000
# 2025-03-27 12:23:27,935 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:23:27,936 - console_logger - DEBUG - O:SPY240930P00589000
# 2025-03-27 12:23:29,106 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-26
# 2025-03-27 12:23:29,106 - console_logger - DEBUG - ************Finished processing day: 2024-09-26***************
# 2025-03-27 12:23:50,678 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:23:50,678 - console_logger - DEBUG - O:SPY240927P00586000
# 2025-03-27 12:23:51,282 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:23:51,283 - console_logger - DEBUG - O:SPY240927C00587000
# 2025-03-27 12:23:52,747 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:23:52,748 - console_logger - DEBUG - O:SPY240927P00589000
# 2025-03-27 12:23:53,375 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:23:53,376 - console_logger - DEBUG - O:SPY240927C00590000
# 2025-03-27 12:23:53,959 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-27
# 2025-03-27 12:24:16,876 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:24:16,877 - console_logger - DEBUG - O:SPY240930P00587000
# 2025-03-27 12:24:18,381 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:24:18,381 - console_logger - DEBUG - O:SPY240930P00589000
# 2025-03-27 12:24:19,592 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-27
# 2025-03-27 12:24:20,341 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:24:20,341 - console_logger - DEBUG - O:SPY241001C00556000
# 2025-03-27 12:24:23,101 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:24:23,101 - console_logger - DEBUG - O:SPY241001C00559000
# 2025-03-27 12:24:41,719 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:24:41,720 - console_logger - DEBUG - O:SPY241001P00584000
# 2025-03-27 12:24:42,405 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:24:42,405 - console_logger - DEBUG - O:SPY241001P00585000
# 2025-03-27 12:24:43,073 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:24:43,073 - console_logger - DEBUG - O:SPY241001P00586000
# 2025-03-27 12:24:43,757 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:24:43,758 - console_logger - DEBUG - O:SPY241001P00587000
# 2025-03-27 12:24:45,503 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:24:45,504 - console_logger - DEBUG - O:SPY241001P00589000
# 2025-03-27 12:24:46,270 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:24:46,271 - console_logger - DEBUG - O:SPY241001P00590000
# 2025-03-27 12:24:46,772 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-27
# 2025-03-27 12:24:46,773 - console_logger - DEBUG - ************Finished processing day: 2024-09-27***************
# 2025-03-27 12:24:46,778 - console_logger - WARNING - Could not find equity date for date: 2024-09-28
# 2025-03-27 12:24:46,783 - console_logger - WARNING - Could not find equity date for date: 2024-09-29
# 2025-03-27 12:25:10,202 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:25:10,202 - console_logger - DEBUG - O:SPY240930P00586000
# 2025-03-27 12:25:10,902 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:25:10,902 - console_logger - DEBUG - O:SPY240930P00587000
# 2025-03-27 12:25:12,085 - console_logger - DEBUG - Processed expiry date 0 for day 2024-09-30
# 2025-03-27 12:25:34,135 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:25:34,135 - console_logger - DEBUG - O:SPY241001P00583000
# 2025-03-27 12:25:35,485 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:25:35,486 - console_logger - DEBUG - O:SPY241001P00585000
# 2025-03-27 12:25:36,875 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:25:36,876 - console_logger - DEBUG - O:SPY241001P00587000
# 2025-03-27 12:25:37,590 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:25:37,590 - console_logger - DEBUG - O:SPY241001P00588000
# 2025-03-27 12:25:38,092 - console_logger - DEBUG - Processed expiry date 1 for day 2024-09-30
# 2025-03-27 12:25:42,208 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:25:42,208 - console_logger - DEBUG - O:SPY241002C00557000
# 2025-03-27 12:26:01,968 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:01,968 - console_logger - DEBUG - O:SPY241002P00582000
# 2025-03-27 12:26:03,352 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:03,352 - console_logger - DEBUG - O:SPY241002P00584000
# 2025-03-27 12:26:04,041 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:04,042 - console_logger - DEBUG - O:SPY241002P00585000
# 2025-03-27 12:26:04,716 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:04,717 - console_logger - DEBUG - O:SPY241002P00586000
# 2025-03-27 12:26:05,536 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:05,537 - console_logger - DEBUG - O:SPY241002P00587000
# 2025-03-27 12:26:06,759 - console_logger - DEBUG - Processed expiry date 2 for day 2024-09-30
# 2025-03-27 12:26:06,760 - console_logger - DEBUG - ************Finished processing day: 2024-09-30***************
# 2025-03-27 12:26:30,112 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:30,113 - console_logger - DEBUG - O:SPY241001P00584000
# 2025-03-27 12:26:32,408 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:32,409 - console_logger - DEBUG - O:SPY241001P00587000
# 2025-03-27 12:26:32,910 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-01
# 2025-03-27 12:26:32,989 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:26:32,990 - console_logger - DEBUG - O:SPY241002C00553000
# 2025-03-27 12:26:56,891 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:56,892 - console_logger - DEBUG - O:SPY241002P00584000
# 2025-03-27 12:26:58,302 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:26:58,303 - console_logger - DEBUG - O:SPY241002P00586000
# 2025-03-27 12:26:59,485 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-01
# 2025-03-27 12:27:21,257 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:27:21,258 - console_logger - DEBUG - O:SPY241003P00583000
# 2025-03-27 12:27:24,818 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-01
# 2025-03-27 12:27:24,819 - console_logger - DEBUG - ************Finished processing day: 2024-10-01***************
# 2025-03-27 12:27:24,904 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:27:24,905 - console_logger - DEBUG - O:SPY241002C00548000
# 2025-03-27 12:27:49,704 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-02
# 2025-03-27 12:28:13,739 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:28:13,740 - console_logger - DEBUG - O:SPY241003P00581000
# 2025-03-27 12:28:14,961 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-02
# 2025-03-27 12:28:41,353 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-02
# 2025-03-27 12:28:41,354 - console_logger - DEBUG - ************Finished processing day: 2024-10-02***************
# 2025-03-27 12:29:07,847 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-03
# 2025-03-27 12:29:33,002 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-03
# 2025-03-27 12:29:57,681 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-03
# 2025-03-27 12:29:57,682 - console_logger - DEBUG - ************Finished processing day: 2024-10-03***************
# 2025-03-27 12:30:22,941 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:30:22,942 - console_logger - DEBUG - O:SPY241004P00588000
# 2025-03-27 12:30:24,164 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-04
# 2025-03-27 12:30:59,159 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:30:59,160 - console_logger - DEBUG - O:SPY241007P00587000
# 2025-03-27 12:31:01,286 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-04
# 2025-03-27 12:31:24,341 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:31:24,341 - console_logger - DEBUG - O:SPY241008P00584000
# 2025-03-27 12:31:27,887 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:31:27,888 - console_logger - DEBUG - O:SPY241008C00589000
# 2025-03-27 12:31:28,007 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:31:28,008 - console_logger - DEBUG - O:SPY241008P00589000
# 2025-03-27 12:31:28,509 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-04
# 2025-03-27 12:31:28,510 - console_logger - DEBUG - ************Finished processing day: 2024-10-04***************
# 2025-03-27 12:31:28,515 - console_logger - WARNING - Could not find equity date for date: 2024-10-05
# 2025-03-27 12:31:28,520 - console_logger - WARNING - Could not find equity date for date: 2024-10-06
# 2025-03-27 12:31:56,202 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:31:56,203 - console_logger - DEBUG - O:SPY241007P00588000
# 2025-03-27 12:31:56,704 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-07
# 2025-03-27 12:32:22,105 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:32:22,106 - console_logger - DEBUG - O:SPY241008P00586000
# 2025-03-27 12:32:24,065 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-07
# 2025-03-27 12:32:48,547 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:32:48,547 - console_logger - DEBUG - O:SPY241009P00587000
# 2025-03-27 12:32:49,203 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:32:49,204 - console_logger - DEBUG - O:SPY241009P00588000
# 2025-03-27 12:32:49,707 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-07
# 2025-03-27 12:32:49,708 - console_logger - DEBUG - ************Finished processing day: 2024-10-07***************
# 2025-03-27 12:33:14,306 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:33:14,307 - console_logger - DEBUG - O:SPY241008P00585000
# 2025-03-27 12:33:15,005 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:33:15,006 - console_logger - DEBUG - O:SPY241008P00586000
# 2025-03-27 12:33:15,887 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:33:15,888 - console_logger - DEBUG - O:SPY241008P00587000
# 2025-03-27 12:33:16,389 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-08
# 2025-03-27 12:33:16,522 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:33:16,523 - console_logger - DEBUG - O:SPY241009C00552000
# 2025-03-27 12:33:40,587 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:33:40,588 - console_logger - DEBUG - O:SPY241009P00584000
# 2025-03-27 12:33:41,968 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:33:41,968 - console_logger - DEBUG - O:SPY241009P00586000
# 2025-03-27 12:33:42,637 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:33:42,638 - console_logger - DEBUG - O:SPY241009P00587000
# 2025-03-27 12:33:43,139 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-08
# 2025-03-27 12:34:06,085 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:34:06,086 - console_logger - DEBUG - O:SPY241010P00584000
# 2025-03-27 12:34:07,452 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:34:07,453 - console_logger - DEBUG - O:SPY241010P00586000
# 2025-03-27 12:34:08,691 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-08
# 2025-03-27 12:34:08,692 - console_logger - DEBUG - ************Finished processing day: 2024-10-08***************
# 2025-03-27 12:34:31,661 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:34:31,662 - console_logger - DEBUG - O:SPY241009P00586000
# 2025-03-27 12:34:33,828 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:34:33,829 - console_logger - DEBUG - O:SPY241009P00589000
# 2025-03-27 12:34:35,016 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-09
# 2025-03-27 12:34:59,008 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:34:59,008 - console_logger - DEBUG - O:SPY241010P00588000
# 2025-03-27 12:34:59,840 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:34:59,840 - console_logger - DEBUG - O:SPY241010P00589000
# 2025-03-27 12:35:01,025 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-09
# 2025-03-27 12:35:26,967 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-09
# 2025-03-27 12:35:26,968 - console_logger - DEBUG - ************Finished processing day: 2024-10-09***************
# 2025-03-27 12:35:52,892 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-10
# 2025-03-27 12:36:18,493 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-10
# 2025-03-27 12:36:18,586 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:18,587 - console_logger - DEBUG - O:SPY241014C00558000
# 2025-03-27 12:36:18,661 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:18,662 - console_logger - DEBUG - O:SPY241014P00558000
# 2025-03-27 12:36:19,358 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:19,359 - console_logger - DEBUG - O:SPY241014C00559000
# 2025-03-27 12:36:19,430 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:19,431 - console_logger - DEBUG - O:SPY241014P00559000
# 2025-03-27 12:36:20,742 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:20,742 - console_logger - DEBUG - O:SPY241014C00561000
# 2025-03-27 12:36:20,819 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:20,820 - console_logger - DEBUG - O:SPY241014P00561000
# 2025-03-27 12:36:21,400 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:21,401 - console_logger - DEBUG - O:SPY241014C00562000
# 2025-03-27 12:36:21,509 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:21,510 - console_logger - DEBUG - O:SPY241014P00562000
# 2025-03-27 12:36:37,316 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:37,317 - console_logger - DEBUG - O:SPY241014C00584000
# 2025-03-27 12:36:37,421 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:37,422 - console_logger - DEBUG - O:SPY241014P00584000
# 2025-03-27 12:36:38,762 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:38,763 - console_logger - DEBUG - O:SPY241014C00586000
# 2025-03-27 12:36:38,853 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:38,854 - console_logger - DEBUG - O:SPY241014P00586000
# 2025-03-27 12:36:39,462 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:39,463 - console_logger - DEBUG - O:SPY241014C00587000
# 2025-03-27 12:36:39,539 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:39,540 - console_logger - DEBUG - O:SPY241014P00587000
# 2025-03-27 12:36:40,138 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:40,139 - console_logger - DEBUG - O:SPY241014C00588000
# 2025-03-27 12:36:40,212 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:40,213 - console_logger - DEBUG - O:SPY241014P00588000
# 2025-03-27 12:36:40,793 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:40,793 - console_logger - DEBUG - O:SPY241014C00589000
# 2025-03-27 12:36:40,863 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:40,864 - console_logger - DEBUG - O:SPY241014P00589000
# 2025-03-27 12:36:42,110 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:42,111 - console_logger - DEBUG - O:SPY241014C00591000
# 2025-03-27 12:36:42,184 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:42,185 - console_logger - DEBUG - O:SPY241014P00591000
# 2025-03-27 12:36:42,788 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:36:42,789 - console_logger - DEBUG - O:SPY241014C00592000
# 2025-03-27 12:36:42,861 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:36:42,861 - console_logger - DEBUG - O:SPY241014P00592000
# 2025-03-27 12:36:43,362 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-10
# 2025-03-27 12:36:43,363 - console_logger - DEBUG - ************Finished processing day: 2024-10-10***************
# 2025-03-27 12:37:07,532 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:37:07,533 - console_logger - DEBUG - O:SPY241011P00593000
# 2025-03-27 12:37:08,736 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-11
# 2025-03-27 12:37:34,996 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-11
# 2025-03-27 12:37:36,608 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:37:36,609 - console_logger - DEBUG - O:SPY241015C00561000
# 2025-03-27 12:38:00,263 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:38:00,264 - console_logger - DEBUG - O:SPY241015P00593000
# 2025-03-27 12:38:00,928 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:38:00,929 - console_logger - DEBUG - O:SPY241015P00594000
# 2025-03-27 12:38:01,429 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-11
# 2025-03-27 12:38:01,430 - console_logger - DEBUG - ************Finished processing day: 2024-10-11***************
# 2025-03-27 12:38:01,435 - console_logger - WARNING - Could not find equity date for date: 2024-10-12
# 2025-03-27 12:38:01,440 - console_logger - WARNING - Could not find equity date for date: 2024-10-13
# 2025-03-27 12:38:24,521 - console_logger - DEBUG - !!!!**********Missing Call contract******
# ...
# 2025-03-27 12:40:02,213 - console_logger - DEBUG - O:SPY241016C00589000
# 2025-03-27 12:40:02,325 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:02,326 - console_logger - DEBUG - O:SPY241016P00589000
# 2025-03-27 12:40:03,621 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:03,622 - console_logger - DEBUG - O:SPY241016C00591000
# 2025-03-27 12:40:03,708 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:03,708 - console_logger - DEBUG - O:SPY241016P00591000
# 2025-03-27 12:40:04,288 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:04,289 - console_logger - DEBUG - O:SPY241016C00592000
# 2025-03-27 12:40:04,368 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:04,369 - console_logger - DEBUG - O:SPY241016P00592000
# 2025-03-27 12:40:04,980 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:04,981 - console_logger - DEBUG - O:SPY241016C00593000
# 2025-03-27 12:40:05,098 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:05,099 - console_logger - DEBUG - O:SPY241016P00593000
# 2025-03-27 12:40:05,686 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:05,686 - console_logger - DEBUG - O:SPY241016C00594000
# 2025-03-27 12:40:05,807 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:05,808 - console_logger - DEBUG - O:SPY241016P00594000
# 2025-03-27 12:40:07,051 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:07,052 - console_logger - DEBUG - O:SPY241016C00596000
# 2025-03-27 12:40:07,132 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:07,133 - console_logger - DEBUG - O:SPY241016P00596000
# 2025-03-27 12:40:07,735 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:07,736 - console_logger - DEBUG - O:SPY241016C00597000
# 2025-03-27 12:40:07,815 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:07,816 - console_logger - DEBUG - O:SPY241016P00597000
# 2025-03-27 12:40:08,404 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:08,405 - console_logger - DEBUG - O:SPY241016C00598000
# 2025-03-27 12:40:08,500 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:08,501 - console_logger - DEBUG - O:SPY241016P00598000
# 2025-03-27 12:40:09,084 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:09,084 - console_logger - DEBUG - O:SPY241016C00599000
# 2025-03-27 12:40:09,151 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:09,152 - console_logger - DEBUG - O:SPY241016P00599000
# 2025-03-27 12:40:10,531 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:10,532 - console_logger - DEBUG - O:SPY241016C00601000
# 2025-03-27 12:40:10,598 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:10,598 - console_logger - DEBUG - O:SPY241016P00601000
# 2025-03-27 12:40:11,099 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-15
# 2025-03-27 12:40:33,815 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:33,815 - console_logger - DEBUG - O:SPY241017C00596000
# 2025-03-27 12:40:33,896 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:33,897 - console_logger - DEBUG - O:SPY241017P00596000
# 2025-03-27 12:40:34,475 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:34,476 - console_logger - DEBUG - O:SPY241017C00597000
# 2025-03-27 12:40:34,564 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:34,565 - console_logger - DEBUG - O:SPY241017P00597000
# 2025-03-27 12:40:35,170 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:35,170 - console_logger - DEBUG - O:SPY241017C00598000
# 2025-03-27 12:40:35,253 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:35,254 - console_logger - DEBUG - O:SPY241017P00598000
# 2025-03-27 12:40:35,854 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:35,854 - console_logger - DEBUG - O:SPY241017C00599000
# 2025-03-27 12:40:35,928 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:35,928 - console_logger - DEBUG - O:SPY241017P00599000
# 2025-03-27 12:40:36,592 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:36,593 - console_logger - DEBUG - O:SPY241017P00600000
# 2025-03-27 12:40:37,170 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:40:37,170 - console_logger - DEBUG - O:SPY241017C00601000
# 2025-03-27 12:40:37,248 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:40:37,249 - console_logger - DEBUG - O:SPY241017P00601000
# 2025-03-27 12:40:37,750 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-15
# 2025-03-27 12:40:37,751 - console_logger - DEBUG - ************Finished processing day: 2024-10-15***************
# 2025-03-27 12:41:02,517 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:41:02,518 - console_logger - DEBUG - O:SPY241016P00593000
# 2025-03-27 12:41:03,262 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:41:03,263 - console_logger - DEBUG - O:SPY241016P00594000
# 2025-03-27 12:41:04,975 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:41:04,975 - console_logger - DEBUG - O:SPY241016C00596000
# 2025-03-27 12:41:05,050 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:41:05,051 - console_logger - DEBUG - O:SPY241016P00596000
# 2025-03-27 12:41:05,552 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-16
# 2025-03-27 12:41:31,464 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:41:31,465 - console_logger - DEBUG - O:SPY241017C00596000
# 2025-03-27 12:41:31,568 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:41:31,569 - console_logger - DEBUG - O:SPY241017P00596000
# 2025-03-27 12:41:32,070 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-16
# 2025-03-27 12:41:57,499 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:41:57,500 - console_logger - DEBUG - O:SPY241018P00596000
# 2025-03-27 12:41:58,002 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-16
# 2025-03-27 12:41:58,003 - console_logger - DEBUG - ************Finished processing day: 2024-10-16***************
# 2025-03-27 12:42:19,643 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:42:19,644 - console_logger - DEBUG - O:SPY241017P00597000
# 2025-03-27 12:42:23,191 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-17
# 2025-03-27 12:42:47,031 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:42:47,032 - console_logger - DEBUG - O:SPY241018P00597000
# 2025-03-27 12:42:47,698 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:42:47,699 - console_logger - DEBUG - O:SPY241018P00598000
# 2025-03-27 12:42:48,396 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:42:48,397 - console_logger - DEBUG - O:SPY241018P00599000
# 2025-03-27 12:42:50,233 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-17
# 2025-03-27 12:42:52,456 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:42:52,457 - console_logger - DEBUG - O:SPY241021C00569000
# 2025-03-27 12:43:16,036 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:43:16,036 - console_logger - DEBUG - O:SPY241021P00598000
# 2025-03-27 12:43:16,748 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:43:16,749 - console_logger - DEBUG - O:SPY241021P00599000
# 2025-03-27 12:43:19,506 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:43:19,507 - console_logger - DEBUG - O:SPY241021P00601000
# 2025-03-27 12:43:20,007 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-17
# 2025-03-27 12:43:20,008 - console_logger - DEBUG - ************Finished processing day: 2024-10-17***************
# 2025-03-27 12:43:53,702 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:43:53,703 - console_logger - DEBUG - O:SPY241018C00601000
# 2025-03-27 12:43:53,895 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:43:53,895 - console_logger - DEBUG - O:SPY241018P00601000
# 2025-03-27 12:43:54,397 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-18
# 2025-03-27 12:44:19,596 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:44:19,597 - console_logger - DEBUG - O:SPY241021P00599000
# 2025-03-27 12:44:20,873 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:44:20,874 - console_logger - DEBUG - O:SPY241021C00601000
# 2025-03-27 12:44:21,453 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-18
# 2025-03-27 12:44:23,624 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:44:23,624 - console_logger - DEBUG - O:SPY241022C00569000
# 2025-03-27 12:44:43,027 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:44:43,027 - console_logger - DEBUG - O:SPY241022P00596000
# 2025-03-27 12:44:44,562 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:44:44,563 - console_logger - DEBUG - O:SPY241022P00598000
# 2025-03-27 12:44:45,146 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:44:45,147 - console_logger - DEBUG - O:SPY241022C00599000
# 2025-03-27 12:44:47,134 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-18
# 2025-03-27 12:44:47,134 - console_logger - DEBUG - ************Finished processing day: 2024-10-18***************
# 2025-03-27 12:44:47,140 - console_logger - WARNING - Could not find equity date for date: 2024-10-19
# 2025-03-27 12:44:47,146 - console_logger - WARNING - Could not find equity date for date: 2024-10-20
# 2025-03-27 12:45:12,044 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:45:12,045 - console_logger - DEBUG - O:SPY241021P00599000
# 2025-03-27 12:45:13,312 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:45:13,313 - console_logger - DEBUG - O:SPY241021C00601000
# 2025-03-27 12:45:13,949 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-21
# 2025-03-27 12:45:37,157 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:45:37,158 - console_logger - DEBUG - O:SPY241022P00597000
# 2025-03-27 12:45:38,512 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:45:38,513 - console_logger - DEBUG - O:SPY241022P00599000
# 2025-03-27 12:45:40,532 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-21
# 2025-03-27 12:45:40,638 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:45:40,639 - console_logger - DEBUG - O:SPY241023C00566000
# 2025-03-27 12:45:41,355 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:45:41,356 - console_logger - DEBUG - O:SPY241023C00567000
# 2025-03-27 12:45:42,050 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:45:42,051 - console_logger - DEBUG - O:SPY241023C00568000
# 2025-03-27 12:45:42,738 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:45:42,739 - console_logger - DEBUG - O:SPY241023C00569000
# 2025-03-27 12:46:04,715 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:46:04,716 - console_logger - DEBUG - O:SPY241023P00598000
# 2025-03-27 12:46:05,314 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:46:05,315 - console_logger - DEBUG - O:SPY241023C00599000
# 2025-03-27 12:46:05,413 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:46:05,414 - console_logger - DEBUG - O:SPY241023P00599000
# 2025-03-27 12:46:06,092 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:46:06,093 - console_logger - DEBUG - O:SPY241023P00600000
# 2025-03-27 12:46:06,675 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:46:06,675 - console_logger - DEBUG - O:SPY241023C00601000
# 2025-03-27 12:46:06,756 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:46:06,756 - console_logger - DEBUG - O:SPY241023P00601000
# 2025-03-27 12:46:07,257 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-21
# 2025-03-27 12:46:07,257 - console_logger - DEBUG - ************Finished processing day: 2024-10-21***************
# 2025-03-27 12:46:32,585 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:46:32,585 - console_logger - DEBUG - O:SPY241022C00597000
# 2025-03-27 12:46:32,726 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:46:32,727 - console_logger - DEBUG - O:SPY241022P00597000
# 2025-03-27 12:46:33,942 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-22
# 2025-03-27 12:47:00,586 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-22
# 2025-03-27 12:47:00,725 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:47:00,726 - console_logger - DEBUG - O:SPY241024C00563000
# 2025-03-27 12:47:03,074 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:47:03,074 - console_logger - DEBUG - O:SPY241024C00566000
# 2025-03-27 12:47:05,217 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:47:05,217 - console_logger - DEBUG - O:SPY241024C00569000
# 2025-03-27 12:47:26,355 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:47:26,356 - console_logger - DEBUG - O:SPY241024C00598000
# 2025-03-27 12:47:26,454 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:47:26,455 - console_logger - DEBUG - O:SPY241024P00598000
# 2025-03-27 12:47:26,955 - console_logger - DEBUG - Processed expiry date 2 for day 2024-10-22
# 2025-03-27 12:47:26,956 - console_logger - DEBUG - ************Finished processing day: 2024-10-22***************
# 2025-03-27 12:47:51,328 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:47:51,328 - console_logger - DEBUG - O:SPY241023P00597000
# 2025-03-27 12:47:51,912 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2025-03-27 12:47:51,913 - console_logger - DEBUG - O:SPY241023C00598000
# 2025-03-27 12:47:51,989 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:47:51,990 - console_logger - DEBUG - O:SPY241023P00598000
# 2025-03-27 12:47:52,491 - console_logger - DEBUG - Processed expiry date 0 for day 2024-10-23
# 2025-03-27 12:48:17,285 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:48:17,286 - console_logger - DEBUG - O:SPY241024P00596000
# 2025-03-27 12:48:18,773 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2025-03-27 12:48:18,773 - console_logger - DEBUG - O:SPY241024P00598000
# 2025-03-27 12:48:19,274 - console_logger - DEBUG - Processed expiry date 1 for day 2024-10-23
# 2025-03-27 12:49:22,373 - console_logger - ERROR - Error processing day 2024-10-23 and DTE 2
# 2025-03-27 12:49:22,375 - console_logger - ERROR - ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
options_df = pd.concat(data['options_quotes'])
options_df['expiry'] = pd.to_datetime(options_df['expiry'], format="%y%m%d").dt.date
options_df = options_df.rename(
            columns={"v": "volume", "vw": "volume_weighted", "o": "open", "c": "close",
                        "h": "high", "l": "low", "t": "timestamp", "n": "number of trades",
                        "a": "trade conditions"})
options_df['time_converted'] = pd.to_datetime(
            options_df["timestamp"], unit="ms").dt.tz_localize(
                pytz.UTC).dt.tz_convert("US/Eastern").dt.tz_localize(None)
options_df =  options_df.merge(
                data['equity_quotes'],how='left', on='time_converted',indicator=True)
# create mapping after the merge: _x => options, _y: equity else unchanged
cols = [col[0:-2] + '_options' if col[-2:] == '_x' else (col[0:-2] +'_equity' if col[-2:] == '_y' else col) for col in options_df.columns]
options_df.columns = cols
options_df.drop(columns=['volume_equity','volume_weighted_equity'], inplace=True)

# pickup only time > 9.30 since some option quotes start @ 9, which is not feasible for analysis

options_df = options_df[(options_df['time_converted'].dt.time > datetime.time(9,30)) & (options_df['time_converted'].dt.time < datetime.time(16,0))]

options_df.reset_index(drop=True, inplace=True)
# for each day calculate equity pct change since open
# options_df.loc[:,'equity_pct_change'] = options_df.loc[:,'open_equity']/options_df.loc[:,'equity_start_price']
options_df['equity_pct_change'] = options_df.loc[:,'open_equity']/options_df.loc[:,'equity_start_price']
# for each day/strike calculate option price pct change since open

#date_options_comb is all possible combinations, then reiterate through them and do the math
date_options_comb = mysqldf("select distinct full_name, date(time_converted) as date from options_df")

#create new column
options_df.loc[:,'options_pct_change'] = None
options_df.loc[:,'options_earliest_open'] = None
for index, row in date_options_comb.iterrows():
    # open price (first) for this combination of option and date
    combination_mask =  (options_df['full_name'] == row['full_name']) & (options_df['time_converted'].dt.date ==
           pd.to_datetime(row['date']).date())
    #pull first price for this combination 
    open_price_opt = options_df.loc[combination_mask,'open_options'].iloc[0]
    #populate this field as well as pct for this combination
    options_df.loc[combination_mask,'options_earliest_open'] = open_price_opt
    options_df.loc[combination_mask,'options_pct_change'] = options_df.loc[combination_mask,'open_options']/options_df.loc[
            combination_mask,'options_earliest_open']

# %%
options_df[options_df['time_converted'].dt.date == datetime.date(2024,10,22)]['time_converted'].dt.time.unique()
# Out:
# array([datetime.time(11, 15), datetime.time(14, 45),
#        datetime.time(15, 15), datetime.time(9, 45), datetime.time(15, 30),
#        datetime.time(13, 0), datetime.time(14, 0), datetime.time(10, 45),
#        datetime.time(10, 0), datetime.time(13, 30), datetime.time(12, 30),
#        datetime.time(12, 45), datetime.time(15, 45),
#        datetime.time(10, 15), datetime.time(11, 30),
#        datetime.time(11, 45), datetime.time(12, 0), datetime.time(12, 15),
#        datetime.time(13, 45), datetime.time(14, 15),
#        datetime.time(10, 30), datetime.time(11, 0), datetime.time(13, 15),
#        datetime.time(15, 0), datetime.time(14, 30)], dtype=object)

# %%
a = options_df[options_df['time_converted'].dt.date == datetime.date(2024,10,22)]['time_converted'].dt.time.unique()

# %%
a
# Out:
# array([datetime.time(11, 15), datetime.time(14, 45),
#        datetime.time(15, 15), datetime.time(9, 45), datetime.time(15, 30),
#        datetime.time(13, 0), datetime.time(14, 0), datetime.time(10, 45),
#        datetime.time(10, 0), datetime.time(13, 30), datetime.time(12, 30),
#        datetime.time(12, 45), datetime.time(15, 45),
#        datetime.time(10, 15), datetime.time(11, 30),
#        datetime.time(11, 45), datetime.time(12, 0), datetime.time(12, 15),
#        datetime.time(13, 45), datetime.time(14, 15),
#        datetime.time(10, 30), datetime.time(11, 0), datetime.time(13, 15),
#        datetime.time(15, 0), datetime.time(14, 30)], dtype=object)

# %%
# options_df = options_df[options_df['time_converted'] < datetime.datetime(2024,4,1)]
options_df.to_csv('0-2DTE_spy_options_07_01_24-08_31_24.csv')
options_df.to_pickle('0-2DTE_spy_options_07_01_24-08_31_24.pkl')
#options_df['time_converted'].max()

# %%
def generateEquityAPIRequestQuotes(ticker: str,startDate: datetime.date,endDate: datetime.date, minutes_freq:int):
    headers = {
        'Authorization': f"Bearer {API_KEY}"
    }
    CSV = False
    if CSV: headers['Accept'] = 'text/csv'
    url = EQUITY_URL.substitute(
                ticker = ticker,
                multiplier = minutes_freq,
                start_date = startDate,
                end_date = endDate
        )
    response = requests.get(url, headers=headers)
    return response
# Out:
# 203958   2024-04-03 13:30:00
# 203959   2024-04-03 13:45:00
# 203960   2024-04-03 14:00:00
# 203961   2024-04-03 14:15:00
# 203962   2024-04-03 14:30:00
# 203963   2024-04-03 14:45:00
# 203964   2024-04-03 15:00:00
# 203965   2024-04-03 15:15:00
# 203966   2024-04-03 15:30:00
# 203967   2024-04-03 15:45:00
# Name: time_converted, dtype: datetime64[ns]

# %%
df_equity_temp = generateEquityAPIRequestQuotes('SPY',startDate,endDate,15)

# %%
options_df[options_df['_merge'] == 'left_only']['time_converted'].unique()
# Out:
# <DatetimeArray>
# ['2024-04-03 11:45:00', '2024-04-03 12:00:00', '2024-04-03 15:15:00',
#  '2024-04-03 12:45:00', '2024-04-03 13:00:00', '2024-04-03 14:30:00',
#  '2024-04-03 15:45:00', '2024-04-03 14:00:00', '2024-04-03 12:30:00',
#  '2024-04-03 13:30:00', '2024-04-03 15:30:00', '2024-04-03 13:45:00',
#  '2024-04-03 14:45:00', '2024-04-03 11:30:00', '2024-04-03 12:15:00',
#  '2024-04-03 13:15:00', '2024-04-03 14:15:00', '2024-04-03 15:00:00']
# Length: 18, dtype: datetime64[ns]

# %%
_temp_df = pd.DataFrame(df_equity_temp.json()['results'])
_temp_df['time_converted'] = pd.to_datetime(_temp_df['t'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('US/Eastern').dt.tz_localize(None)

# %%
df_equity_temp.json().keys()
# Out:
# dict_keys(['ticker', 'queryCount', 'resultsCount', 'adjusted', 'results', 'status', 'request_id', 'count', 'next_url'])

# %%
df_equity_temp.json()['next_url']
# Out:
# 'https://api.polygon.io/v2/aggs/ticker/SPY/range/15/minute/1712158200000/2024-05-30?cursor=bGltaXQ9NTAwMDAmc29ydD1hc2M'
