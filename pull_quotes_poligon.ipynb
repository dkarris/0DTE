# %%
import pandas as pd
import numpy as np
import datetime
import requests
from string import Template
import pytz
import math
import logging
import time
from pandasql import sqldf

# %%
pd.options.display.max_rows = 50
pd.options.display.max_columns = 100

# %%
# API  STUFF
API_KEY = 'qf_ZzJ56DKvoDrfdw3OVFlzGW_UfZ9el'
OPTIONS_URL = Template('https://api.polygon.io/v2/aggs/ticker/$ticker/range/$multiplier/minute/$start_date/$end_date?adjusted=true&sort=asc&limit=50000')
EQUITY_URL =  Template('https://api.polygon.io/v2/aggs/ticker/$ticker/range/$multiplier/minute/$start_date/$end_date?adjusted=true&sort=asc&limit=50000')

# logger stuff
console_logger = logging.getLogger('console_logger')
file_logger = logging.getLogger('file_logger')
file_logger.setLevel(logging.DEBUG)
console_logger.setLevel(logging.DEBUG)
file_handler = logging.FileHandler('research_options_05-11-24.log')
console_handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)
file_logger.addHandler(file_handler)
console_logger.addHandler(console_handler)
# logger stuff end

#pandassql stuff
mysqldf = lambda q: sqldf(q, globals())

# %%
startDate = datetime.date(2023,3,1)
endDate = datetime.date(2023,5,30)
equity_symbol = 'SPY'
max_expiry_dte = 2
max_strikes_from_open_price = 0.03 # pct wise from  open equity price
strike_step = 1

# %%
def generateOptionsAPIRequestQuotes(optionstring:str, startDate: datetime.date, endDate: datetime.date, minutes_freq:int):
    CSV = False
    headers = {
             'Authorization': f"Bearer {API_KEY}",
        }
    if CSV: headers['Accept'] = 'text/csv'
    url = OPTIONS_URL.substitute(
                ticker = optionstring,
                multiplier = minutes_freq,
                start_date = startDate.strftime('%Y-%m-%d'),
                end_date = endDate.strftime('%Y-%m-%d')
    )
    response = requests.get(url, headers=headers)
    return response
def generateEquityAPIRequestQuotes(ticker: str,startDate: datetime.date,endDate: datetime.date, minutes_freq:int):
    headers = {
        'Authorization': f"Bearer {API_KEY}"
    }
    CSV = False
    if CSV: headers['Accept'] = 'text/csv'
    url = EQUITY_URL.substitute(
                ticker = ticker,
                multiplier = minutes_freq,
                start_date = startDate,
                end_date = endDate
        )
    response = requests.get(url, headers=headers)
    return response
def getOptionsData(ticker,startDate,endDate,minutes_freq):
    def enhancePulledDataFromPolygon(df:pd.DataFrame, optionticker:str,
                                     option_full_name: str,
                                     optiontype: str, option_strike:float,
                                     option_expiry_date: datetime.date):
        """Gets df obtained from Polygon api request and enriches with 
           columns such as ticker, strike, option type, expiry date
           since the data from Polygon doesn't contain this.
           option parametes are passed from the calling func as they were used to query
           poligon API
         """
        df['ticker'] = optionticker
        df['full_name'] = option_full_name
        df['type'] = optiontype
        df['strike'] = option_strike
        df['expiry'] = option_expiry_date
        return df
    dates_range = pd.date_range(start=startDate, end=endDate, freq='D')
    equity_quotes = generateEquityAPIRequestQuotes(ticker,startDate,endDate,minutes_freq)
    equity_df = pd.DataFrame()
    if equity_quotes.status_code == 200:
        equity_df = pd.DataFrame(equity_quotes.json()['results'])
        equity_df = equity_df.rename(
            columns={"v": "volume", "vw": "volume_weighted", "o": "open", "c": "close",
                        "h": "high", "l": "low", "t": "timestamp", "n": "number of trades",
                        "a": "trade conditions"})
        equity_df['time_converted'] = pd.to_datetime(
            equity_df["timestamp"], unit="ms").dt.tz_localize(
                pytz.UTC).dt.tz_convert("US/Eastern").dt.tz_localize(None)
    else:
        print (equity_quotes.text)
        raise RuntimeError("Error when processing API call to equity prices")
    
    
    df_quotes = []
    for day in dates_range:
        # first pull equity open price for this day
        try:
            # pull  first open price in candle after 9.30
            central_price = equity_df[(equity_df['time_converted'].dt.date == day.date()) & 
                                            (equity_df['time_converted'].dt.time > datetime.time(9,30))]['open'].iloc[0]
            # Calculate strike math
            strike_upper_limit = math.ceil(central_price*(1+max_strikes_from_open_price))
            strike_lower_limit = math.floor(central_price*(1-max_strikes_from_open_price))
            strike_range = list(range(strike_lower_limit,strike_upper_limit,strike_step))
        except IndexError:
            file_logger.warning('Could not find equity date for date: ' + str(day.date()))   
            console_logger.warning('Could not find equity date for date: ' + str(day.date()))
            continue   
        if np.is_busday(day.date()):
            # create API requests for days having DTE 0 and less than max_expiry_dte
            for DTE in range(0,max_expiry_dte+1):
                # for each date pull all options expiring on this date and within max_strikes_from_open_price
                contract_date = (day.date() + pd.tseries.offsets.BDay(n = DTE))
                                 #datetime.timedelta(days = DTE))
                # if the contract expiry date is weekend (sat,sun) then skip
                if contract_date.isoweekday() in [6,7]:
                    file_logger.info(f'Contract expiry date {contract_date} is on expiring on Weekend for options trading on {day.date}. Skipping this expiry date ')
                    console_logger.debug(f'Contract expiry date {contract_date} is on expiring on Weekend for options trading on {day.date}. Skipping this expiry date ')
                    continue
                else:
                    contract_date = contract_date.strftime('%y%m%d')
                for strike in strike_range:
                    #for each strike retrieve for specific contract expiry date (DTE(contract_date)) for specific date (day) quotes
                    # example: "O:SPY230519C00417000"
                    call_contract_ticker = 'O:SPY'+ contract_date+'C'+'00'+str(int(strike)*1000)
                    put_contract_ticker =  'O:SPY'+ contract_date+'P'+'00'+str(int(strike)*1000)
                    file_logger.info('Pulling call: ' + call_contract_ticker)
                    call_response = generateOptionsAPIRequestQuotes(call_contract_ticker,day,day,minutes_freq)
                    if call_response.status_code != 200:
                        console_logger.debug(call_contract_ticker)
                        console_logger.debut(call_response.text)
                        raise RuntimeError("API returned not success when trying to get call options")
                    
                    # potentially maybe zero results since extra holidays or data corruption, then skip it
                    if int(call_response.json()['resultsCount']) > 0:
                        df_strike_call = pd.DataFrame(call_response.json()['results'])
                        df_strike_call = enhancePulledDataFromPolygon(
                                    df=df_strike_call, optionticker=ticker,option_full_name=call_contract_ticker,
                                    optiontype='call', option_strike=strike,
                                    option_expiry_date=contract_date
                                )
                        df_strike_call['equity_start_price'] = central_price
                        df_quotes.append(df_strike_call)
                    else:
                        file_logger.debug(f'!!!!**********Missing Call contract from API return******')
                        file_logger.debug(call_contract_ticker)
                        console_logger.debug(f'!!!!**********Missing Call contract******')
                        console_logger.debug(call_contract_ticker)
                    
                    file_logger.info('Pulling put: ' + put_contract_ticker)
                    put_response = generateOptionsAPIRequestQuotes(put_contract_ticker,day,day,minutes_freq)
                    if put_response.status_code != 200:
                        console_logger.debug(put_contract_ticker)
                        console_logger.debut(put_response.text)
                        raise RuntimeError("API returned not success when trying to get put options")
                    
                    if int(put_response.json()['resultsCount']) > 0:
                        df_strike_put = pd.DataFrame(put_response.json()['results'])
                        df_strike_put = enhancePulledDataFromPolygon(
                                    df=df_strike_put, optionticker=ticker,option_full_name=put_contract_ticker,
                                    optiontype='put', option_strike=strike,
                                    option_expiry_date=contract_date
                                )
                        df_strike_put['equity_start_price'] = central_price
                        df_quotes.append(df_strike_put)
                    else:
                        file_logger.debug(f'!!!!**********Missing Put contract from API return******')
                        file_logger.debug(put_contract_ticker)
                        console_logger.debug(f'!!!!**********Missing Put contract******')
                        console_logger.debug(put_contract_ticker)
                    file_logger.info(f"""Appended these file contracts for day {day.date()}:{call_contract_ticker} and  {put_contract_ticker}""")
                    time.sleep(0.5)
                console_logger.debug(f'Processed expiry date {DTE} for day {day.date()}')
        console_logger.debug(f'************Finished processing day: {day.date()}***************')        
    console_logger.debug(f'************Finished running function***************')        
    file_logger.debug(f'************Finished running function***************')        
    return {
        'options_quotes': df_quotes,
        'equity_quotes' : equity_df
    }

# %%
## main body
file_logger.info('*****************************New Run***********************************')
# response is dict with options data in ['options_quotes] (list of options dfs) and equity data in ['equity_quotes] - df
data = getOptionsData('SPY',datetime.date(2023,9,1), datetime.date(2023,12,31
                                                                   ),15)
# Out:
# 2024-05-12 11:16:26,873 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-01
# 2024-05-12 11:16:27,273 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:27,273 - console_logger - DEBUG - O:SPY230904C00438000
# 2024-05-12 11:16:27,776 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:27,777 - console_logger - DEBUG - O:SPY230904P00438000
# 2024-05-12 11:16:28,672 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:28,672 - console_logger - DEBUG - O:SPY230904C00439000
# 2024-05-12 11:16:29,059 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:29,060 - console_logger - DEBUG - O:SPY230904P00439000
# 2024-05-12 11:16:29,941 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:29,941 - console_logger - DEBUG - O:SPY230904C00440000
# 2024-05-12 11:16:30,314 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:30,315 - console_logger - DEBUG - O:SPY230904P00440000
# 2024-05-12 11:16:31,191 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:31,192 - console_logger - DEBUG - O:SPY230904C00441000
# 2024-05-12 11:16:31,566 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:31,567 - console_logger - DEBUG - O:SPY230904P00441000
# 2024-05-12 11:16:32,433 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:32,434 - console_logger - DEBUG - O:SPY230904C00442000
# 2024-05-12 11:16:32,850 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:32,850 - console_logger - DEBUG - O:SPY230904P00442000
# 2024-05-12 11:16:33,770 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:33,771 - console_logger - DEBUG - O:SPY230904C00443000
# 2024-05-12 11:16:34,186 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:34,187 - console_logger - DEBUG - O:SPY230904P00443000
# 2024-05-12 11:16:35,095 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:35,095 - console_logger - DEBUG - O:SPY230904C00444000
# 2024-05-12 11:16:35,479 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:35,480 - console_logger - DEBUG - O:SPY230904P00444000
# 2024-05-12 11:16:36,362 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:36,363 - console_logger - DEBUG - O:SPY230904C00445000
# 2024-05-12 11:16:36,748 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:36,748 - console_logger - DEBUG - O:SPY230904P00445000
# 2024-05-12 11:16:37,623 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:37,624 - console_logger - DEBUG - O:SPY230904C00446000
# 2024-05-12 11:16:38,016 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:38,016 - console_logger - DEBUG - O:SPY230904P00446000
# 2024-05-12 11:16:38,950 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:38,952 - console_logger - DEBUG - O:SPY230904C00447000
# 2024-05-12 11:16:39,477 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:39,478 - console_logger - DEBUG - O:SPY230904P00447000
# 2024-05-12 11:16:40,510 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:40,511 - console_logger - DEBUG - O:SPY230904C00448000
# 2024-05-12 11:16:40,893 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:40,894 - console_logger - DEBUG - O:SPY230904P00448000
# 2024-05-12 11:16:41,817 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:41,818 - console_logger - DEBUG - O:SPY230904C00449000
# 2024-05-12 11:16:42,212 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:42,213 - console_logger - DEBUG - O:SPY230904P00449000
# 2024-05-12 11:16:43,179 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:43,180 - console_logger - DEBUG - O:SPY230904C00450000
# 2024-05-12 11:16:43,642 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:43,643 - console_logger - DEBUG - O:SPY230904P00450000
# 2024-05-12 11:16:44,556 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:44,557 - console_logger - DEBUG - O:SPY230904C00451000
# 2024-05-12 11:16:44,952 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:44,953 - console_logger - DEBUG - O:SPY230904P00451000
# 2024-05-12 11:16:45,873 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:45,873 - console_logger - DEBUG - O:SPY230904C00452000
# 2024-05-12 11:16:46,260 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:46,261 - console_logger - DEBUG - O:SPY230904P00452000
# 2024-05-12 11:16:47,146 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:47,146 - console_logger - DEBUG - O:SPY230904C00453000
# 2024-05-12 11:16:47,560 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:47,560 - console_logger - DEBUG - O:SPY230904P00453000
# 2024-05-12 11:16:48,477 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:48,477 - console_logger - DEBUG - O:SPY230904C00454000
# 2024-05-12 11:16:48,898 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:48,899 - console_logger - DEBUG - O:SPY230904P00454000
# 2024-05-12 11:16:49,860 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:49,861 - console_logger - DEBUG - O:SPY230904C00455000
# 2024-05-12 11:16:50,263 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:50,264 - console_logger - DEBUG - O:SPY230904P00455000
# 2024-05-12 11:16:51,171 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:51,172 - console_logger - DEBUG - O:SPY230904C00456000
# 2024-05-12 11:16:51,692 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:51,692 - console_logger - DEBUG - O:SPY230904P00456000
# 2024-05-12 11:16:52,650 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:52,651 - console_logger - DEBUG - O:SPY230904C00457000
# 2024-05-12 11:16:53,101 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:53,102 - console_logger - DEBUG - O:SPY230904P00457000
# 2024-05-12 11:16:54,072 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:54,073 - console_logger - DEBUG - O:SPY230904C00458000
# 2024-05-12 11:16:54,515 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:54,516 - console_logger - DEBUG - O:SPY230904P00458000
# 2024-05-12 11:16:55,483 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:55,484 - console_logger - DEBUG - O:SPY230904C00459000
# 2024-05-12 11:16:55,945 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:55,945 - console_logger - DEBUG - O:SPY230904P00459000
# 2024-05-12 11:16:56,922 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:56,922 - console_logger - DEBUG - O:SPY230904C00460000
# 2024-05-12 11:16:57,378 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:57,378 - console_logger - DEBUG - O:SPY230904P00460000
# 2024-05-12 11:16:58,288 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:58,288 - console_logger - DEBUG - O:SPY230904C00461000
# 2024-05-12 11:16:58,690 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:58,690 - console_logger - DEBUG - O:SPY230904P00461000
# 2024-05-12 11:16:59,577 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:16:59,577 - console_logger - DEBUG - O:SPY230904C00462000
# 2024-05-12 11:16:59,969 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:16:59,970 - console_logger - DEBUG - O:SPY230904P00462000
# 2024-05-12 11:17:00,875 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:17:00,876 - console_logger - DEBUG - O:SPY230904C00463000
# 2024-05-12 11:17:01,300 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:17:01,300 - console_logger - DEBUG - O:SPY230904P00463000
# 2024-05-12 11:17:02,190 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:17:02,191 - console_logger - DEBUG - O:SPY230904C00464000
# 2024-05-12 11:17:02,610 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:17:02,610 - console_logger - DEBUG - O:SPY230904P00464000
# 2024-05-12 11:17:03,524 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:17:03,524 - console_logger - DEBUG - O:SPY230904C00465000
# 2024-05-12 11:17:03,915 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:17:03,916 - console_logger - DEBUG - O:SPY230904P00465000
# 2024-05-12 11:17:04,418 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-01
# 2024-05-12 11:17:48,634 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-01
# 2024-05-12 11:17:48,634 - console_logger - DEBUG - ************Finished processing day: 2023-09-01***************
# 2024-05-12 11:17:48,644 - console_logger - WARNING - Could not find equity date for date: 2023-09-02
# 2024-05-12 11:17:48,651 - console_logger - WARNING - Could not find equity date for date: 2023-09-03
# 2024-05-12 11:17:48,656 - console_logger - WARNING - Could not find equity date for date: 2023-09-04
# 2024-05-12 11:18:32,940 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-05
# 2024-05-12 11:19:11,509 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:19:11,510 - console_logger - DEBUG - O:SPY230906P00461000
# 2024-05-12 11:19:15,728 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-05
# 2024-05-12 11:20:01,966 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:20:01,966 - console_logger - DEBUG - O:SPY230907P00462000
# 2024-05-12 11:20:03,369 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:20:03,370 - console_logger - DEBUG - O:SPY230907P00463000
# 2024-05-12 11:20:03,872 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-05
# 2024-05-12 11:20:03,872 - console_logger - DEBUG - ************Finished processing day: 2023-09-05***************
# 2024-05-12 11:20:48,706 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-06
# 2024-05-12 11:21:33,627 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:21:33,628 - console_logger - DEBUG - O:SPY230907P00461000
# 2024-05-12 11:21:34,130 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-06
# 2024-05-12 11:22:18,546 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:22:18,546 - console_logger - DEBUG - O:SPY230908P00461000
# 2024-05-12 11:22:19,049 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-06
# 2024-05-12 11:22:19,049 - console_logger - DEBUG - ************Finished processing day: 2023-09-06***************
# 2024-05-12 11:23:07,252 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:23:07,252 - console_logger - DEBUG - O:SPY230907P00456000
# 2024-05-12 11:23:09,326 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-07
# 2024-05-12 11:23:55,339 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-07
# 2024-05-12 11:23:55,792 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:23:55,792 - console_logger - DEBUG - O:SPY230911C00430000
# 2024-05-12 11:23:57,683 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:23:57,684 - console_logger - DEBUG - O:SPY230911C00431000
# 2024-05-12 11:23:59,060 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:23:59,060 - console_logger - DEBUG - O:SPY230911C00432000
# 2024-05-12 11:24:36,876 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-07
# 2024-05-12 11:24:36,876 - console_logger - DEBUG - ************Finished processing day: 2023-09-07***************
# 2024-05-12 11:25:13,583 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:25:13,584 - console_logger - DEBUG - O:SPY230908P00456000
# 2024-05-12 11:25:19,716 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-08
# 2024-05-12 11:26:01,264 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-08
# 2024-05-12 11:26:01,705 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:26:01,706 - console_logger - DEBUG - O:SPY230912C00432000
# 2024-05-12 11:26:39,476 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:26:39,477 - console_logger - DEBUG - O:SPY230912P00457000
# 2024-05-12 11:26:42,695 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-08
# 2024-05-12 11:26:42,695 - console_logger - DEBUG - ************Finished processing day: 2023-09-08***************
# 2024-05-12 11:26:42,703 - console_logger - WARNING - Could not find equity date for date: 2023-09-09
# 2024-05-12 11:26:42,708 - console_logger - WARNING - Could not find equity date for date: 2023-09-10
# 2024-05-12 11:27:18,036 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:27:18,038 - console_logger - DEBUG - O:SPY230911P00458000
# 2024-05-12 11:27:22,579 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:27:22,580 - console_logger - DEBUG - O:SPY230911P00461000
# 2024-05-12 11:27:23,081 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-11
# 2024-05-12 11:28:02,111 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:28:02,112 - console_logger - DEBUG - O:SPY230912P00461000
# 2024-05-12 11:28:02,614 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-11
# 2024-05-12 11:28:02,998 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:28:02,999 - console_logger - DEBUG - O:SPY230913C00434000
# 2024-05-12 11:28:40,666 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-11
# 2024-05-12 11:28:40,667 - console_logger - DEBUG - ************Finished processing day: 2023-09-11***************
# 2024-05-12 11:29:22,115 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-12
# 2024-05-12 11:30:03,761 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-12
# 2024-05-12 11:30:44,037 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-12
# 2024-05-12 11:30:44,041 - console_logger - DEBUG - ************Finished processing day: 2023-09-12***************
# 2024-05-12 11:31:27,095 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:31:27,096 - console_logger - DEBUG - O:SPY230913P00459000
# 2024-05-12 11:31:29,354 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-13
# 2024-05-12 11:32:09,286 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-13
# 2024-05-12 11:32:50,819 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-13
# 2024-05-12 11:32:50,820 - console_logger - DEBUG - ************Finished processing day: 2023-09-13***************
# 2024-05-12 11:33:31,952 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:33:31,952 - console_logger - DEBUG - O:SPY230914P00462000
# 2024-05-12 11:33:32,454 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-14
# 2024-05-12 11:34:10,893 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:34:10,894 - console_logger - DEBUG - O:SPY230915P00461000
# 2024-05-12 11:34:12,788 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-14
# 2024-05-12 11:34:53,354 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-14
# 2024-05-12 11:34:53,355 - console_logger - DEBUG - ************Finished processing day: 2023-09-14***************
# 2024-05-12 11:35:31,823 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-15
# 2024-05-12 11:36:09,256 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-15
# 2024-05-12 11:36:09,694 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:36:09,694 - console_logger - DEBUG - O:SPY230919C00433000
# 2024-05-12 11:36:13,742 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:36:13,743 - console_logger - DEBUG - O:SPY230919C00436000
# 2024-05-12 11:36:46,643 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:36:46,643 - console_logger - DEBUG - O:SPY230919P00458000
# 2024-05-12 11:36:48,574 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-15
# 2024-05-12 11:36:48,575 - console_logger - DEBUG - ************Finished processing day: 2023-09-15***************
# 2024-05-12 11:36:48,580 - console_logger - WARNING - Could not find equity date for date: 2023-09-16
# 2024-05-12 11:36:48,586 - console_logger - WARNING - Could not find equity date for date: 2023-09-17
# 2024-05-12 11:36:49,011 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:36:49,012 - console_logger - DEBUG - O:SPY230918C00429000
# 2024-05-12 11:36:51,747 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:36:51,748 - console_logger - DEBUG - O:SPY230918C00431000
# 2024-05-12 11:37:27,303 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:37:27,304 - console_logger - DEBUG - O:SPY230918P00455000
# 2024-05-12 11:37:28,675 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:37:28,677 - console_logger - DEBUG - O:SPY230918P00456000
# 2024-05-12 11:37:29,179 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-18
# 2024-05-12 11:38:09,057 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-18
# 2024-05-12 11:38:13,696 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:38:13,697 - console_logger - DEBUG - O:SPY230920C00432000
# 2024-05-12 11:38:15,065 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:38:15,065 - console_logger - DEBUG - O:SPY230920C00433000
# 2024-05-12 11:38:44,507 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:38:44,508 - console_logger - DEBUG - O:SPY230920P00454000
# 2024-05-12 11:38:47,204 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:38:47,205 - console_logger - DEBUG - O:SPY230920P00456000
# 2024-05-12 11:38:47,707 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-18
# 2024-05-12 11:38:47,708 - console_logger - DEBUG - ************Finished processing day: 2023-09-18***************
# 2024-05-12 11:38:48,244 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:38:48,244 - console_logger - DEBUG - O:SPY230919C00429000
# 2024-05-12 11:39:24,769 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:39:24,769 - console_logger - DEBUG - O:SPY230919P00455000
# 2024-05-12 11:39:26,964 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-19
# 2024-05-12 11:40:05,127 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-19
# 2024-05-12 11:40:05,521 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:40:05,522 - console_logger - DEBUG - O:SPY230921C00429000
# 2024-05-12 11:40:38,807 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:40:38,808 - console_logger - DEBUG - O:SPY230921P00454000
# 2024-05-12 11:40:41,350 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:40:41,350 - console_logger - DEBUG - O:SPY230921P00456000
# 2024-05-12 11:40:41,852 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-19
# 2024-05-12 11:40:41,852 - console_logger - DEBUG - ************Finished processing day: 2023-09-19***************
# 2024-05-12 11:41:15,328 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:41:15,328 - console_logger - DEBUG - O:SPY230920P00455000
# 2024-05-12 11:41:16,569 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:41:16,569 - console_logger - DEBUG - O:SPY230920P00456000
# 2024-05-12 11:41:17,867 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:41:17,867 - console_logger - DEBUG - O:SPY230920P00457000
# 2024-05-12 11:41:18,369 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-20
# 2024-05-12 11:41:54,333 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-20
# 2024-05-12 11:42:30,806 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:42:30,807 - console_logger - DEBUG - O:SPY230922P00457000
# 2024-05-12 11:42:31,309 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-20
# 2024-05-12 11:42:31,309 - console_logger - DEBUG - ************Finished processing day: 2023-09-20***************
# 2024-05-12 11:42:32,993 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:42:32,993 - console_logger - DEBUG - O:SPY230921C00422000
# 2024-05-12 11:42:35,524 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:42:35,525 - console_logger - DEBUG - O:SPY230921C00424000
# 2024-05-12 11:43:07,291 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-21
# 2024-05-12 11:43:43,893 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-21
# 2024-05-12 11:44:20,744 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-21
# 2024-05-12 11:44:20,745 - console_logger - DEBUG - ************Finished processing day: 2023-09-21***************
# 2024-05-12 11:44:21,155 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:44:21,156 - console_logger - DEBUG - O:SPY230922C00418000
# 2024-05-12 11:44:56,762 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-22
# 2024-05-12 11:44:58,457 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:44:58,458 - console_logger - DEBUG - O:SPY230925C00419000
# 2024-05-12 11:45:34,330 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-22
# 2024-05-12 11:46:11,854 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-22
# 2024-05-12 11:46:11,854 - console_logger - DEBUG - ************Finished processing day: 2023-09-22***************
# 2024-05-12 11:46:11,860 - console_logger - WARNING - Could not find equity date for date: 2023-09-23
# 2024-05-12 11:46:11,865 - console_logger - WARNING - Could not find equity date for date: 2023-09-24
# 2024-05-12 11:46:13,651 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:46:13,652 - console_logger - DEBUG - O:SPY230925C00417000
# 2024-05-12 11:46:14,918 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:46:14,918 - console_logger - DEBUG - O:SPY230925C00418000
# 2024-05-12 11:46:52,165 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-25
# 2024-05-12 11:47:30,639 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-25
# 2024-05-12 11:47:31,216 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:47:31,217 - console_logger - DEBUG - O:SPY230927C00416000
# 2024-05-12 11:47:37,953 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:47:37,953 - console_logger - DEBUG - O:SPY230927C00421000
# 2024-05-12 11:48:06,717 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-25
# 2024-05-12 11:48:06,717 - console_logger - DEBUG - ************Finished processing day: 2023-09-25***************
# 2024-05-12 11:48:42,353 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-26
# 2024-05-12 11:49:17,616 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:49:17,617 - console_logger - DEBUG - O:SPY230927P00442000
# 2024-05-12 11:49:18,119 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-26
# 2024-05-12 11:49:53,307 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-26
# 2024-05-12 11:49:53,307 - console_logger - DEBUG - ************Finished processing day: 2023-09-26***************
# 2024-05-12 11:50:29,216 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-27
# 2024-05-12 11:51:04,862 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-27
# 2024-05-12 11:51:42,135 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-27
# 2024-05-12 11:51:42,136 - console_logger - DEBUG - ************Finished processing day: 2023-09-27***************
# 2024-05-12 11:52:15,750 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-28
# 2024-05-12 11:52:50,470 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-28
# 2024-05-12 11:52:51,085 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:52:51,086 - console_logger - DEBUG - O:SPY231002C00412000
# 2024-05-12 11:52:53,902 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:52:53,903 - console_logger - DEBUG - O:SPY231002C00414000
# 2024-05-12 11:52:56,463 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:52:56,463 - console_logger - DEBUG - O:SPY231002C00416000
# 2024-05-12 11:53:24,947 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-28
# 2024-05-12 11:53:24,947 - console_logger - DEBUG - ************Finished processing day: 2023-09-28***************
# 2024-05-12 11:53:59,569 - console_logger - DEBUG - Processed expiry date 0 for day 2023-09-29
# 2024-05-12 11:54:33,616 - console_logger - DEBUG - Processed expiry date 1 for day 2023-09-29
# 2024-05-12 11:55:07,327 - console_logger - DEBUG - Processed expiry date 2 for day 2023-09-29
# 2024-05-12 11:55:07,327 - console_logger - DEBUG - ************Finished processing day: 2023-09-29***************
# 2024-05-12 11:55:07,334 - console_logger - WARNING - Could not find equity date for date: 2023-09-30
# 2024-05-12 11:55:07,338 - console_logger - WARNING - Could not find equity date for date: 2023-10-01
# 2024-05-12 11:55:56,817 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-02
# 2024-05-12 11:56:40,053 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-02
# 2024-05-12 11:56:40,432 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:56:40,433 - console_logger - DEBUG - O:SPY231004C00414000
# 2024-05-12 11:56:43,648 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 11:56:43,648 - console_logger - DEBUG - O:SPY231004C00416000
# 2024-05-12 11:57:22,212 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:57:22,213 - console_logger - DEBUG - O:SPY231004P00439000
# 2024-05-12 11:57:24,546 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-02
# 2024-05-12 11:57:24,546 - console_logger - DEBUG - ************Finished processing day: 2023-10-02***************
# 2024-05-12 11:58:01,645 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:58:01,646 - console_logger - DEBUG - O:SPY231003P00437000
# 2024-05-12 11:58:03,443 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-03
# 2024-05-12 11:58:47,331 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-03
# 2024-05-12 11:59:28,343 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 11:59:28,344 - console_logger - DEBUG - O:SPY231005P00438000
# 2024-05-12 11:59:28,846 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-03
# 2024-05-12 11:59:28,846 - console_logger - DEBUG - ************Finished processing day: 2023-10-03***************
# 2024-05-12 12:00:08,664 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-04
# 2024-05-12 12:00:49,821 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-04
# 2024-05-12 12:01:29,348 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-04
# 2024-05-12 12:01:29,349 - console_logger - DEBUG - ************Finished processing day: 2023-10-04***************
# 2024-05-12 12:02:05,544 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-05
# 2024-05-12 12:02:41,158 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-05
# 2024-05-12 12:03:18,249 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-05
# 2024-05-12 12:03:18,249 - console_logger - DEBUG - ************Finished processing day: 2023-10-05***************
# 2024-05-12 12:03:53,918 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-06
# 2024-05-12 12:04:31,262 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-06
# 2024-05-12 12:04:34,526 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:04:34,526 - console_logger - DEBUG - O:SPY231010C00411000
# 2024-05-12 12:05:07,204 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-06
# 2024-05-12 12:05:07,204 - console_logger - DEBUG - ************Finished processing day: 2023-10-06***************
# 2024-05-12 12:05:07,210 - console_logger - WARNING - Could not find equity date for date: 2023-10-07
# 2024-05-12 12:05:07,215 - console_logger - WARNING - Could not find equity date for date: 2023-10-08
# 2024-05-12 12:05:43,494 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-09
# 2024-05-12 12:06:18,526 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-09
# 2024-05-12 12:06:20,984 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:06:20,985 - console_logger - DEBUG - O:SPY231011C00416000
# 2024-05-12 12:06:54,887 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:06:54,887 - console_logger - DEBUG - O:SPY231011P00441000
# 2024-05-12 12:06:55,389 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-09
# 2024-05-12 12:06:55,390 - console_logger - DEBUG - ************Finished processing day: 2023-10-09***************
# 2024-05-12 12:07:31,986 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-10
# 2024-05-12 12:08:07,054 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-10
# 2024-05-12 12:08:42,699 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-10
# 2024-05-12 12:08:42,699 - console_logger - DEBUG - ************Finished processing day: 2023-10-10***************
# 2024-05-12 12:09:14,548 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:09:14,548 - console_logger - DEBUG - O:SPY231011P00446000
# 2024-05-12 12:09:15,792 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:09:15,793 - console_logger - DEBUG - O:SPY231011P00447000
# 2024-05-12 12:09:18,385 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:09:18,386 - console_logger - DEBUG - O:SPY231011P00449000
# 2024-05-12 12:09:18,888 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-11
# 2024-05-12 12:09:53,538 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:09:53,538 - console_logger - DEBUG - O:SPY231012P00448000
# 2024-05-12 12:09:54,818 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:09:54,819 - console_logger - DEBUG - O:SPY231012P00449000
# 2024-05-12 12:09:55,321 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-11
# 2024-05-12 12:10:31,768 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-11
# 2024-05-12 12:10:31,768 - console_logger - DEBUG - ************Finished processing day: 2023-10-11***************
# 2024-05-12 12:11:05,165 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:11:05,165 - console_logger - DEBUG - O:SPY231012P00447000
# 2024-05-12 12:11:06,527 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:11:06,528 - console_logger - DEBUG - O:SPY231012P00448000
# 2024-05-12 12:11:07,030 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-12
# 2024-05-12 12:11:43,563 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:11:43,564 - console_logger - DEBUG - O:SPY231013P00448000
# 2024-05-12 12:11:44,066 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-12
# 2024-05-12 12:12:19,426 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:12:19,426 - console_logger - DEBUG - O:SPY231016P00448000
# 2024-05-12 12:12:19,928 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-12
# 2024-05-12 12:12:19,928 - console_logger - DEBUG - ************Finished processing day: 2023-10-12***************
# 2024-05-12 12:12:53,455 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:12:53,456 - console_logger - DEBUG - O:SPY231013P00447000
# 2024-05-12 12:12:55,404 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-13
# 2024-05-12 12:13:29,859 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:13:29,859 - console_logger - DEBUG - O:SPY231016P00447000
# 2024-05-12 12:13:31,665 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-13
# 2024-05-12 12:14:05,223 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:14:05,223 - console_logger - DEBUG - O:SPY231017P00447000
# 2024-05-12 12:14:06,483 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:14:06,483 - console_logger - DEBUG - O:SPY231017P00448000
# 2024-05-12 12:14:06,985 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-13
# 2024-05-12 12:14:06,985 - console_logger - DEBUG - ************Finished processing day: 2023-10-13***************
# 2024-05-12 12:14:06,992 - console_logger - WARNING - Could not find equity date for date: 2023-10-14
# 2024-05-12 12:14:06,998 - console_logger - WARNING - Could not find equity date for date: 2023-10-15
# 2024-05-12 12:14:44,854 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-16
# 2024-05-12 12:15:20,217 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-16
# 2024-05-12 12:15:56,489 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-16
# 2024-05-12 12:15:56,489 - console_logger - DEBUG - ************Finished processing day: 2023-10-16***************
# 2024-05-12 12:16:33,742 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-17
# 2024-05-12 12:17:11,198 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-17
# 2024-05-12 12:17:48,497 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-17
# 2024-05-12 12:17:48,497 - console_logger - DEBUG - ************Finished processing day: 2023-10-17***************
# 2024-05-12 12:18:25,444 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-18
# 2024-05-12 12:19:00,953 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-18
# 2024-05-12 12:19:37,020 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-18
# 2024-05-12 12:19:37,020 - console_logger - DEBUG - ************Finished processing day: 2023-10-18***************
# 2024-05-12 12:20:12,648 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-19
# 2024-05-12 12:20:49,202 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-19
# 2024-05-12 12:20:49,673 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:20:49,674 - console_logger - DEBUG - O:SPY231023C00417000
# 2024-05-12 12:21:24,445 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-19
# 2024-05-12 12:21:24,445 - console_logger - DEBUG - ************Finished processing day: 2023-10-19***************
# 2024-05-12 12:21:58,352 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-20
# 2024-05-12 12:22:32,013 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-20
# 2024-05-12 12:23:07,317 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-20
# 2024-05-12 12:23:07,317 - console_logger - DEBUG - ************Finished processing day: 2023-10-20***************
# 2024-05-12 12:23:07,323 - console_logger - WARNING - Could not find equity date for date: 2023-10-21
# 2024-05-12 12:23:07,328 - console_logger - WARNING - Could not find equity date for date: 2023-10-22
# 2024-05-12 12:23:41,409 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-23
# 2024-05-12 12:23:44,499 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:23:44,500 - console_logger - DEBUG - O:SPY231024C00407000
# 2024-05-12 12:23:45,865 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:23:45,865 - console_logger - DEBUG - O:SPY231024C00408000
# 2024-05-12 12:24:15,513 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-23
# 2024-05-12 12:24:17,392 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:24:17,393 - console_logger - DEBUG - O:SPY231025C00406000
# 2024-05-12 12:24:18,691 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:24:18,692 - console_logger - DEBUG - O:SPY231025C00407000
# 2024-05-12 12:24:20,004 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:24:20,005 - console_logger - DEBUG - O:SPY231025C00408000
# 2024-05-12 12:24:49,372 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-23
# 2024-05-12 12:24:49,372 - console_logger - DEBUG - ************Finished processing day: 2023-10-23***************
# 2024-05-12 12:25:24,086 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-24
# 2024-05-12 12:25:58,088 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:25:58,089 - console_logger - DEBUG - O:SPY231025P00436000
# 2024-05-12 12:25:58,591 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-24
# 2024-05-12 12:26:00,220 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:26:00,220 - console_logger - DEBUG - O:SPY231026C00411000
# 2024-05-12 12:26:33,405 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-24
# 2024-05-12 12:26:33,405 - console_logger - DEBUG - ************Finished processing day: 2023-10-24***************
# 2024-05-12 12:26:33,786 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:26:33,787 - console_logger - DEBUG - O:SPY231025C00407000
# 2024-05-12 12:27:06,962 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-25
# 2024-05-12 12:27:41,367 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-25
# 2024-05-12 12:28:15,197 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-25
# 2024-05-12 12:28:15,197 - console_logger - DEBUG - ************Finished processing day: 2023-10-25***************
# 2024-05-12 12:28:48,800 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-26
# 2024-05-12 12:29:22,981 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-26
# 2024-05-12 12:29:56,978 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-26
# 2024-05-12 12:29:56,978 - console_logger - DEBUG - ************Finished processing day: 2023-10-26***************
# 2024-05-12 12:30:29,927 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-27
# 2024-05-12 12:31:02,254 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-27
# 2024-05-12 12:31:34,410 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-27
# 2024-05-12 12:31:34,410 - console_logger - DEBUG - ************Finished processing day: 2023-10-27***************
# 2024-05-12 12:31:34,417 - console_logger - WARNING - Could not find equity date for date: 2023-10-28
# 2024-05-12 12:31:34,421 - console_logger - WARNING - Could not find equity date for date: 2023-10-29
# 2024-05-12 12:32:08,036 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-30
# 2024-05-12 12:32:41,890 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-30
# 2024-05-12 12:33:15,614 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-30
# 2024-05-12 12:33:15,614 - console_logger - DEBUG - ************Finished processing day: 2023-10-30***************
# 2024-05-12 12:33:50,257 - console_logger - DEBUG - Processed expiry date 0 for day 2023-10-31
# 2024-05-12 12:34:24,358 - console_logger - DEBUG - Processed expiry date 1 for day 2023-10-31
# 2024-05-12 12:34:26,032 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 12:34:26,033 - console_logger - DEBUG - O:SPY231102C00403000
# 2024-05-12 12:34:58,666 - console_logger - DEBUG - Processed expiry date 2 for day 2023-10-31
# 2024-05-12 12:34:58,666 - console_logger - DEBUG - ************Finished processing day: 2023-10-31***************
# 2024-05-12 12:35:43,795 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-01
# 2024-05-12 12:36:28,909 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-01
# 2024-05-12 12:37:10,352 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-01
# 2024-05-12 12:37:10,352 - console_logger - DEBUG - ************Finished processing day: 2023-11-01***************
# 2024-05-12 12:37:51,479 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-02
# 2024-05-12 12:38:34,841 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-02
# 2024-05-12 12:39:15,585 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-02
# 2024-05-12 12:39:15,585 - console_logger - DEBUG - ************Finished processing day: 2023-11-02***************
# 2024-05-12 12:39:55,212 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-03
# 2024-05-12 12:40:33,851 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-03
# 2024-05-12 12:41:06,338 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:41:06,338 - console_logger - DEBUG - O:SPY231107P00443000
# 2024-05-12 12:41:10,456 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:41:10,456 - console_logger - DEBUG - O:SPY231107P00446000
# 2024-05-12 12:41:11,980 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:41:11,981 - console_logger - DEBUG - O:SPY231107P00447000
# 2024-05-12 12:41:12,483 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-03
# 2024-05-12 12:41:12,483 - console_logger - DEBUG - ************Finished processing day: 2023-11-03***************
# 2024-05-12 12:41:12,490 - console_logger - WARNING - Could not find equity date for date: 2023-11-04
# 2024-05-12 12:41:12,495 - console_logger - WARNING - Could not find equity date for date: 2023-11-05
# 2024-05-12 12:41:47,239 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:41:47,240 - console_logger - DEBUG - O:SPY231106P00446000
# 2024-05-12 12:41:50,103 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:41:50,103 - console_logger - DEBUG - O:SPY231106P00448000
# 2024-05-12 12:41:50,605 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-06
# 2024-05-12 12:42:29,976 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:42:29,976 - console_logger - DEBUG - O:SPY231107P00447000
# 2024-05-12 12:42:31,308 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:42:31,309 - console_logger - DEBUG - O:SPY231107P00448000
# 2024-05-12 12:42:31,811 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-06
# 2024-05-12 12:43:14,184 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:43:14,184 - console_logger - DEBUG - O:SPY231108P00447000
# 2024-05-12 12:43:15,783 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:43:15,783 - console_logger - DEBUG - O:SPY231108P00448000
# 2024-05-12 12:43:16,285 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-06
# 2024-05-12 12:43:16,285 - console_logger - DEBUG - ************Finished processing day: 2023-11-06***************
# 2024-05-12 12:43:55,733 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-07
# 2024-05-12 12:44:33,622 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-07
# 2024-05-12 12:45:03,619 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:45:03,620 - console_logger - DEBUG - O:SPY231109P00443000
# 2024-05-12 12:45:10,780 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:45:10,781 - console_logger - DEBUG - O:SPY231109P00448000
# 2024-05-12 12:45:11,282 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-07
# 2024-05-12 12:45:11,282 - console_logger - DEBUG - ************Finished processing day: 2023-11-07***************
# 2024-05-12 12:45:48,241 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:45:48,242 - console_logger - DEBUG - O:SPY231108P00449000
# 2024-05-12 12:45:50,021 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-08
# 2024-05-12 12:46:22,773 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:46:22,774 - console_logger - DEBUG - O:SPY231109P00448000
# 2024-05-12 12:46:26,220 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-08
# 2024-05-12 12:47:01,458 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:47:01,459 - console_logger - DEBUG - O:SPY231110P00448000
# 2024-05-12 12:47:02,695 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:47:02,696 - console_logger - DEBUG - O:SPY231110P00449000
# 2024-05-12 12:47:04,745 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-08
# 2024-05-12 12:47:04,745 - console_logger - DEBUG - ************Finished processing day: 2023-11-08***************
# 2024-05-12 12:47:41,519 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-09
# 2024-05-12 12:48:18,545 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-09
# 2024-05-12 12:48:50,384 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:48:50,384 - console_logger - DEBUG - O:SPY231113P00446000
# 2024-05-12 12:48:54,396 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:48:54,397 - console_logger - DEBUG - O:SPY231113P00449000
# 2024-05-12 12:48:55,625 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:48:55,625 - console_logger - DEBUG - O:SPY231113P00450000
# 2024-05-12 12:48:56,127 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-09
# 2024-05-12 12:48:56,127 - console_logger - DEBUG - ************Finished processing day: 2023-11-09***************
# 2024-05-12 12:49:33,490 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:49:33,490 - console_logger - DEBUG - O:SPY231110P00449000
# 2024-05-12 12:49:33,992 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-10
# 2024-05-12 12:50:11,135 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-10
# 2024-05-12 12:50:44,880 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 12:50:44,880 - console_logger - DEBUG - O:SPY231114P00448000
# 2024-05-12 12:50:46,721 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-10
# 2024-05-12 12:50:46,721 - console_logger - DEBUG - ************Finished processing day: 2023-11-10***************
# 2024-05-12 12:50:46,727 - console_logger - WARNING - Could not find equity date for date: 2023-11-11
# ...
# 2024-05-12 13:04:33,498 - console_logger - DEBUG - O:SPY231123P00460000
# 2024-05-12 13:04:34,378 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:34,378 - console_logger - DEBUG - O:SPY231123C00461000
# 2024-05-12 13:04:34,732 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:34,732 - console_logger - DEBUG - O:SPY231123P00461000
# 2024-05-12 13:04:35,587 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:35,588 - console_logger - DEBUG - O:SPY231123C00462000
# 2024-05-12 13:04:35,953 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:35,953 - console_logger - DEBUG - O:SPY231123P00462000
# 2024-05-12 13:04:36,818 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:36,818 - console_logger - DEBUG - O:SPY231123C00463000
# 2024-05-12 13:04:37,170 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:37,170 - console_logger - DEBUG - O:SPY231123P00463000
# 2024-05-12 13:04:38,030 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:38,031 - console_logger - DEBUG - O:SPY231123C00464000
# 2024-05-12 13:04:38,394 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:38,394 - console_logger - DEBUG - O:SPY231123P00464000
# 2024-05-12 13:04:39,267 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:39,267 - console_logger - DEBUG - O:SPY231123C00465000
# 2024-05-12 13:04:39,624 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:39,624 - console_logger - DEBUG - O:SPY231123P00465000
# 2024-05-12 13:04:40,523 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:40,524 - console_logger - DEBUG - O:SPY231123C00466000
# 2024-05-12 13:04:40,882 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:40,883 - console_logger - DEBUG - O:SPY231123P00466000
# 2024-05-12 13:04:41,747 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:41,748 - console_logger - DEBUG - O:SPY231123C00467000
# 2024-05-12 13:04:42,116 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:42,117 - console_logger - DEBUG - O:SPY231123P00467000
# 2024-05-12 13:04:42,972 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:42,972 - console_logger - DEBUG - O:SPY231123C00468000
# 2024-05-12 13:04:43,326 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:43,327 - console_logger - DEBUG - O:SPY231123P00468000
# 2024-05-12 13:04:44,200 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:04:44,201 - console_logger - DEBUG - O:SPY231123C00469000
# 2024-05-12 13:04:44,579 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:04:44,580 - console_logger - DEBUG - O:SPY231123P00469000
# 2024-05-12 13:04:45,082 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-22
# 2024-05-12 13:05:19,343 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:05:19,344 - console_logger - DEBUG - O:SPY231124P00468000
# 2024-05-12 13:05:20,625 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:05:20,626 - console_logger - DEBUG - O:SPY231124P00469000
# 2024-05-12 13:05:21,128 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-22
# 2024-05-12 13:05:21,128 - console_logger - DEBUG - ************Finished processing day: 2023-11-22***************
# 2024-05-12 13:05:21,134 - console_logger - WARNING - Could not find equity date for date: 2023-11-23
# 2024-05-12 13:05:55,659 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:05:55,660 - console_logger - DEBUG - O:SPY231124P00467000
# 2024-05-12 13:05:56,518 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:05:56,518 - console_logger - DEBUG - O:SPY231124C00468000
# 2024-05-12 13:05:56,875 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:05:56,876 - console_logger - DEBUG - O:SPY231124P00468000
# 2024-05-12 13:05:57,378 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-24
# 2024-05-12 13:06:26,020 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:06:26,021 - console_logger - DEBUG - O:SPY231127P00463000
# 2024-05-12 13:06:27,280 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:06:27,280 - console_logger - DEBUG - O:SPY231127P00464000
# 2024-05-12 13:06:29,823 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:06:29,823 - console_logger - DEBUG - O:SPY231127P00466000
# 2024-05-12 13:06:31,330 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:06:31,331 - console_logger - DEBUG - O:SPY231127P00467000
# 2024-05-12 13:06:32,745 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:06:32,746 - console_logger - DEBUG - O:SPY231127P00468000
# 2024-05-12 13:06:33,247 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-24
# 2024-05-12 13:06:33,604 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:06:33,604 - console_logger - DEBUG - O:SPY231128C00441000
# 2024-05-12 13:07:02,119 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:02,119 - console_logger - DEBUG - O:SPY231128P00463000
# 2024-05-12 13:07:03,361 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:03,361 - console_logger - DEBUG - O:SPY231128P00464000
# 2024-05-12 13:07:04,609 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:04,610 - console_logger - DEBUG - O:SPY231128P00465000
# 2024-05-12 13:07:05,829 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:05,829 - console_logger - DEBUG - O:SPY231128P00466000
# 2024-05-12 13:07:07,121 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:07,122 - console_logger - DEBUG - O:SPY231128P00467000
# 2024-05-12 13:07:08,358 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:08,359 - console_logger - DEBUG - O:SPY231128P00468000
# 2024-05-12 13:07:08,861 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-24
# 2024-05-12 13:07:08,861 - console_logger - DEBUG - ************Finished processing day: 2023-11-24***************
# 2024-05-12 13:07:08,866 - console_logger - WARNING - Could not find equity date for date: 2023-11-25
# 2024-05-12 13:07:08,870 - console_logger - WARNING - Could not find equity date for date: 2023-11-26
# 2024-05-12 13:07:40,396 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:40,396 - console_logger - DEBUG - O:SPY231127P00464000
# 2024-05-12 13:07:42,900 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:42,901 - console_logger - DEBUG - O:SPY231127P00466000
# 2024-05-12 13:07:44,159 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:07:44,160 - console_logger - DEBUG - O:SPY231127P00467000
# 2024-05-12 13:07:44,662 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-27
# 2024-05-12 13:08:18,689 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:08:18,689 - console_logger - DEBUG - O:SPY231128P00466000
# 2024-05-12 13:08:20,467 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-27
# 2024-05-12 13:08:51,889 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:08:51,890 - console_logger - DEBUG - O:SPY231129P00464000
# 2024-05-12 13:08:53,312 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:08:53,312 - console_logger - DEBUG - O:SPY231129P00465000
# 2024-05-12 13:08:54,620 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:08:54,621 - console_logger - DEBUG - O:SPY231129P00466000
# 2024-05-12 13:08:55,532 - console_logger - DEBUG - !!!!**********Missing Call contract******
# 2024-05-12 13:08:55,533 - console_logger - DEBUG - O:SPY231129C00467000
# 2024-05-12 13:08:55,898 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:08:55,898 - console_logger - DEBUG - O:SPY231129P00467000
# 2024-05-12 13:08:56,400 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-27
# 2024-05-12 13:08:56,400 - console_logger - DEBUG - ************Finished processing day: 2023-11-27***************
# 2024-05-12 13:09:30,495 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:09:30,496 - console_logger - DEBUG - O:SPY231128P00465000
# 2024-05-12 13:09:31,730 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:09:31,731 - console_logger - DEBUG - O:SPY231128P00466000
# 2024-05-12 13:09:33,572 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-28
# 2024-05-12 13:10:08,906 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:10:08,907 - console_logger - DEBUG - O:SPY231129P00466000
# 2024-05-12 13:10:10,216 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:10:10,217 - console_logger - DEBUG - O:SPY231129P00467000
# 2024-05-12 13:10:10,718 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-28
# 2024-05-12 13:10:43,876 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:10:43,877 - console_logger - DEBUG - O:SPY231130P00464000
# 2024-05-12 13:10:45,130 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:10:45,130 - console_logger - DEBUG - O:SPY231130P00465000
# 2024-05-12 13:10:46,390 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:10:46,390 - console_logger - DEBUG - O:SPY231130P00466000
# 2024-05-12 13:10:47,656 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:10:47,657 - console_logger - DEBUG - O:SPY231130P00467000
# 2024-05-12 13:10:48,159 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-28
# 2024-05-12 13:10:48,159 - console_logger - DEBUG - ************Finished processing day: 2023-11-28***************
# 2024-05-12 13:11:19,288 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:11:19,289 - console_logger - DEBUG - O:SPY231129P00467000
# 2024-05-12 13:11:21,774 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:11:21,774 - console_logger - DEBUG - O:SPY231129P00469000
# 2024-05-12 13:11:23,011 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:11:23,012 - console_logger - DEBUG - O:SPY231129P00470000
# 2024-05-12 13:11:24,284 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:11:24,285 - console_logger - DEBUG - O:SPY231129P00471000
# 2024-05-12 13:11:24,787 - console_logger - DEBUG - Processed expiry date 0 for day 2023-11-29
# 2024-05-12 13:11:59,287 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:11:59,287 - console_logger - DEBUG - O:SPY231130P00469000
# 2024-05-12 13:12:00,527 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:12:00,528 - console_logger - DEBUG - O:SPY231130P00470000
# 2024-05-12 13:12:01,765 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:12:01,766 - console_logger - DEBUG - O:SPY231130P00471000
# 2024-05-12 13:12:02,267 - console_logger - DEBUG - Processed expiry date 1 for day 2023-11-29
# 2024-05-12 13:12:32,538 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:12:32,539 - console_logger - DEBUG - O:SPY231201P00466000
# 2024-05-12 13:12:35,148 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:12:35,149 - console_logger - DEBUG - O:SPY231201P00468000
# 2024-05-12 13:12:36,529 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:12:36,529 - console_logger - DEBUG - O:SPY231201P00469000
# 2024-05-12 13:12:39,241 - console_logger - DEBUG - !!!!**********Missing Put contract******
# 2024-05-12 13:12:39,242 - console_logger - DEBUG - O:SPY231201P00471000
# 2024-05-12 13:12:39,744 - console_logger - DEBUG - Processed expiry date 2 for day 2023-11-29
# 2024-05-12 13:12:39,744 - console_logger - DEBUG - ************Finished processing day: 2023-11-29***************
# 2024-05-12 13:12:39,750 - console_logger - WARNING - Could not find equity date for date: 2023-11-30
# 2024-05-12 13:12:39,754 - console_logger - WARNING - Could not find equity date for date: 2023-12-01
# 2024-05-12 13:12:39,759 - console_logger - WARNING - Could not find equity date for date: 2023-12-02
# 2024-05-12 13:12:39,765 - console_logger - WARNING - Could not find equity date for date: 2023-12-03
# 2024-05-12 13:12:39,769 - console_logger - WARNING - Could not find equity date for date: 2023-12-04
# 2024-05-12 13:12:39,774 - console_logger - WARNING - Could not find equity date for date: 2023-12-05
# 2024-05-12 13:12:39,779 - console_logger - WARNING - Could not find equity date for date: 2023-12-06
# 2024-05-12 13:12:39,785 - console_logger - WARNING - Could not find equity date for date: 2023-12-07
# 2024-05-12 13:12:39,792 - console_logger - WARNING - Could not find equity date for date: 2023-12-08
# 2024-05-12 13:12:39,797 - console_logger - WARNING - Could not find equity date for date: 2023-12-09
# 2024-05-12 13:12:39,803 - console_logger - WARNING - Could not find equity date for date: 2023-12-10
# 2024-05-12 13:12:39,807 - console_logger - WARNING - Could not find equity date for date: 2023-12-11
# 2024-05-12 13:12:39,813 - console_logger - WARNING - Could not find equity date for date: 2023-12-12
# 2024-05-12 13:12:39,817 - console_logger - WARNING - Could not find equity date for date: 2023-12-13
# 2024-05-12 13:12:39,826 - console_logger - WARNING - Could not find equity date for date: 2023-12-14
# 2024-05-12 13:12:39,833 - console_logger - WARNING - Could not find equity date for date: 2023-12-15
# 2024-05-12 13:12:39,841 - console_logger - WARNING - Could not find equity date for date: 2023-12-16
# 2024-05-12 13:12:39,848 - console_logger - WARNING - Could not find equity date for date: 2023-12-17
# 2024-05-12 13:12:39,855 - console_logger - WARNING - Could not find equity date for date: 2023-12-18
# 2024-05-12 13:12:39,860 - console_logger - WARNING - Could not find equity date for date: 2023-12-19
# 2024-05-12 13:12:39,867 - console_logger - WARNING - Could not find equity date for date: 2023-12-20
# 2024-05-12 13:12:39,873 - console_logger - WARNING - Could not find equity date for date: 2023-12-21
# 2024-05-12 13:12:39,878 - console_logger - WARNING - Could not find equity date for date: 2023-12-22
# 2024-05-12 13:12:39,884 - console_logger - WARNING - Could not find equity date for date: 2023-12-23
# 2024-05-12 13:12:39,890 - console_logger - WARNING - Could not find equity date for date: 2023-12-24
# 2024-05-12 13:12:39,897 - console_logger - WARNING - Could not find equity date for date: 2023-12-25
# 2024-05-12 13:12:39,903 - console_logger - WARNING - Could not find equity date for date: 2023-12-26
# 2024-05-12 13:12:39,909 - console_logger - WARNING - Could not find equity date for date: 2023-12-27
# 2024-05-12 13:12:39,915 - console_logger - WARNING - Could not find equity date for date: 2023-12-28
# 2024-05-12 13:12:39,921 - console_logger - WARNING - Could not find equity date for date: 2023-12-29
# 2024-05-12 13:12:39,928 - console_logger - WARNING - Could not find equity date for date: 2023-12-30
# 2024-05-12 13:12:39,934 - console_logger - WARNING - Could not find equity date for date: 2023-12-31
# 2024-05-12 13:12:39,934 - console_logger - DEBUG - ************Finished running function***************

# %%
options_df = pd.concat(data['options_quotes'])
options_df['expiry'] = pd.to_datetime(options_df['expiry'], format="%y%m%d").dt.date
options_df = options_df.rename(
            columns={"v": "volume", "vw": "volume_weighted", "o": "open", "c": "close",
                        "h": "high", "l": "low", "t": "timestamp", "n": "number of trades",
                        "a": "trade conditions"})
options_df['time_converted'] = pd.to_datetime(
            options_df["timestamp"], unit="ms").dt.tz_localize(
                pytz.UTC).dt.tz_convert("US/Eastern").dt.tz_localize(None)
options_df =  options_df.merge(
                data['equity_quotes'],how='left', on='time_converted',indicator=True)
# create mapping after the merge: _x => options, _y: equity else unchanged
cols = [col[0:-2] + '_options' if col[-2:] == '_x' else (col[0:-2] +'_equity' if col[-2:] == '_y' else col) for col in options_df.columns]
options_df.columns = cols
options_df.drop(columns=['volume_equity','volume_weighted_equity'], inplace=True)

# pickup only time > 9.30 since some option quotes start @ 9, which is not feasible for analysis

options_df = options_df[(options_df['time_converted'].dt.time > datetime.time(9,30)) & (options_df['time_converted'].dt.time < datetime.time(16,0))]

options_df.reset_index(drop=True, inplace=True)
# for each day calculate equity pct change since open
# options_df.loc[:,'equity_pct_change'] = options_df.loc[:,'open_equity']/options_df.loc[:,'equity_start_price']
options_df['equity_pct_change'] = options_df.loc[:,'open_equity']/options_df.loc[:,'equity_start_price']
# for each day/strike calculate option price pct change since open

#date_options_comb is all possible combinations, then reiterate through them and do the math
date_options_comb = mysqldf("select distinct full_name, date(time_converted) as date from options_df")

#create new column
options_df.loc[:,'options_pct_change'] = None
options_df.loc[:,'options_earliest_open'] = None
for index, row in date_options_comb.iterrows():
    # open price (first) for this combination of option and date
    combination_mask =  (options_df['full_name'] == row['full_name']) & (options_df['time_converted'].dt.date ==
           pd.to_datetime(row['date']).date())
    #pull first price for this combination 
    open_price_opt = options_df.loc[combination_mask,'open_options'].iloc[0]
    #populate this field as well as pct for this combination
    options_df.loc[combination_mask,'options_earliest_open'] = open_price_opt
    options_df.loc[combination_mask,'options_pct_change'] = options_df.loc[combination_mask,'open_options']/options_df.loc[
            combination_mask,'options_earliest_open']

# %%
options_df.to_csv('0-2DTE_spy_options_01Sep23-31Dec23.csv')
options_df.to_pickle('0-2DTE_spy_options_01Sep23-31Dec23.pkl')
#options_df['time_converted'].max()

# %%
options_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 options_df
#
# NameError: name 'options_df' is not defined
